# %%
import pandas as pd

# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
from gensim import corpora, models
np.random.seed(2020)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\P4L\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
stemmer = SnowballStemmer('english')

# %%
def clear_text(text):
    text = re.sub('<code>(.|\n)*?<\/code>', '', text)
    text = re.sub(r'(\<(/?[^>]+)>)', '', text)
    return text

def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess(text):
    text = clear_text(text)
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %%
data = pd.read_csv('../../dataset/optimal_data.csv')
data = data.head(10000)

# %%
tags_set = set()
def topic_count(text):
    ww = text.split('|')
    zz = list()
    for i in ww:
        zz.append(lemmatize_stemming(i))
    for i in zz:
        tags_set.add(i)
    return text
data['post_tags'].map(topic_count)
# Out:
# 0                                         assembly|msp430
# 1                                                 unity3d
# 2        java|algorithm|sorting|data-structures|quicksort
# 3                                             python|kivy
# 4                        r|latex|r-markdown|knitr|tinytex
#                               ...
# 9995    java|spring-mvc|reactive-programming|spring-we...
# 9996                 c#|asp.net|blazor|blazor-server-side
# 9997    javascript|android|cordova|ionic-framework|ionic4
# 9998                         css|angular|angular-material
# 9999    amazon-web-services|aws-glue|aws-glue-data-cat...
# Name: post_tags, Length: 10000, dtype: object

# %%
tags_set
# Out:
# {'aem',
#  'boost-process',
#  'google-material-icon',
#  'cordova',
#  'normal',
#  'type-paramet',
#  'twilio-funct',
#  'user32',
#  'lora',
#  'verif',
#  'codepag',
#  'webdriv',
#  'authent',
#  'file-read',
#  'opencv-stitch',
#  'variadic-funct',
#  'log4js-nod',
#  'macos-catalina',
#  'offline-cach',
#  'regex-group',
#  'google-apis-explor',
#  'rfe',
#  'color',
#  'samsung-s8',
#  'nopcommerc',
#  'androidx',
#  'pusher',
#  'ajaxcontroltoolkit',
#  'errorbar',
#  'ml.net',
#  'union-typ',
#  'api',
#  'memori',
#  'sql-loader',
#  'fade',
#  'ansibl',
#  'ckeditor',
#  'spring',
#  'databrick',
#  'tableview',
#  'mapper',
#  'filenam',
#  'grafana',
#  'project-reactor',
#  'maco',
#  'msix',
#  'mine',
#  'similar',
#  'acumatica-kb',
#  'netti',
#  'memsql',
#  'android-json',
#  'python-multithread',
#  'content-typ',
#  'spss',
#  'voiceov',
#  'linear-regress',
#  'stackdriv',
#  'cygwin',
#  'changelisten',
#  'hot-reload',
#  'angular-univers',
#  'iana',
#  'bayesian-network',
#  'node-fetch',
#  'uitabbar',
#  'django-filt',
#  'dfs',
#  'react-script',
#  'pymysql',
#  'gridsom',
#  'testflight',
#  'xamarin.io',
#  'teradata-sql-assist',
#  'gnupg',
#  'linker-script',
#  'aws-java-sdk',
#  'file-comparison',
#  'theorem-prov',
#  'debian',
#  'gevent',
#  'pack',
#  'android-support-librari',
#  'shinyj',
#  'fast-ai',
#  'google-cloud-datastor',
#  'progress-4gl',
#  'netezza',
#  'poker',
#  'file',
#  'xcodebuild',
#  'webbot',
#  'aws-organ',
#  'loss-funct',
#  'slice',
#  'tti',
#  'odoo-12',
#  'react-native-gifted-chat',
#  'mex',
#  'lazy-load',
#  'kivi',
#  'mathnet-numer',
#  'ajv',
#  'scatter-plot',
#  'react-native-flatlist',
#  'cross-correl',
#  'angular-service-work',
#  'google-cloud-build',
#  'amazon-s',
#  'flv',
#  'type-pun',
#  'resili',
#  'uipath-studio',
#  'creation',
#  '3d-model',
#  'code-gener',
#  'toarray',
#  'lighthous',
#  'splitpanel',
#  'python-3.7.4',
#  'database-design',
#  'password-encrypt',
#  'android-jetpack-compos',
#  'applepay',
#  'git-bash',
#  'exit-cod',
#  'fullscreen',
#  'multithread',
#  'spring-boot',
#  'dialogbasedapp',
#  'callback',
#  'fopen',
#  'webpack-html-load',
#  'sonarscann',
#  'php-7',
#  'list',
#  'icon',
#  'input-mask',
#  'webdriver-w3c-spec',
#  'arduino-id',
#  'refit',
#  'pandas-bokeh',
#  'unsupervised-learn',
#  'visibl',
#  'papapars',
#  'daemon',
#  'kubernetes-job',
#  'geohash',
#  'react-rout',
#  'excel-formula',
#  'command-prompt',
#  'stock',
#  'consist',
#  'connexion',
#  'srcset',
#  'owl-carousel-2',
#  'modelica',
#  'polybas',
#  'material-compon',
#  'dev-c++',
#  'cdn',
#  'gradl',
#  'google-cloud-compos',
#  'arcgi',
#  'getoverlappedresult',
#  'viewmodel',
#  'ilogg',
#  'mpi4pi',
#  'is-empti',
#  'safari',
#  'microcontrol',
#  'ticker',
#  'android-permiss',
#  'material-t',
#  'allocatable-array',
#  'eclipse-2019-09',
#  'gpgpu',
#  'software-distribut',
#  'tomee-8',
#  'powershell-2.0',
#  'fire-and-forget',
#  'dom',
#  'vuforia',
#  'pariti',
#  'uimodalpresentationstyl',
#  'pulumi',
#  '.net-core-3.0',
#  'union',
#  'android-network',
#  'android-renderscript',
#  'google-sheets-api',
#  'dotnet-httpcli',
#  'probabl',
#  'css',
#  'pyspark',
#  'match',
#  'google-cloud-dataproc',
#  'bignum',
#  'multiple-vers',
#  'ngx-mydatepick',
#  'countdown',
#  'record',
#  'azure-autom',
#  'lettuc',
#  'parseint',
#  'nativecal',
#  'pentaho-spoon',
#  'on-screen-keyboard',
#  'sendkey',
#  'dask',
#  'cast',
#  'custom-funct',
#  'vue-test-util',
#  'go',
#  'bing-api',
#  'amazon-vpc',
#  'amazon-elasticach',
#  'uiwebview',
#  'lsf',
#  'httpclient',
#  'tinymce-4',
#  'c-string',
#  'presto',
#  'image-upload',
#  'microsoft-graph-calendar',
#  'wtform',
#  'xstate',
#  'android-modul',
#  'comput',
#  'nested-loop',
#  'gitlab-ci',
#  'mysql-python',
#  'rsa',
#  'delphi-7',
#  'microsoft-cognit',
#  'freeradius',
#  'uefi',
#  'kasperski',
#  'typeloadexcept',
#  'translat',
#  'expect',
#  'function',
#  'matlab-figur',
#  'azure-webjobssdk',
#  'date-differ',
#  'tensorflow-serv',
#  'integration-test',
#  'unsigned-integ',
#  'object-storag',
#  'xamarin.shel',
#  'gnuplot',
#  'matplotlib-basemap',
#  'session-vari',
#  'intel',
#  'n1ql',
#  'collector',
#  'web-scrap',
#  'docx',
#  'google-fin',
#  'display-templ',
#  'racket',
#  'typo3-7.6.x',
#  'wolfram-mathematica',
#  'django-model-field',
#  'graphql-subscript',
#  'odp.net',
#  'concaten',
#  'decompil',
#  'get-map',
#  'jekyll-them',
#  'ios-simul',
#  'spring-cloud-stream',
#  'soapfault',
#  'uiscen',
#  'glm-math',
#  'python-attr',
#  'query-perform',
#  'openssl',
#  'data-min',
#  'privoxi',
#  'compiler-warn',
#  'browserifi',
#  'textjoin',
#  'channel',
#  'dronekit-python',
#  'dotnet-tool',
#  'react-native-f',
#  'sqlconnect',
#  'dotnet-dev-cert',
#  'appinstal',
#  'url-rewrite-modul',
#  'rbenv',
#  'smartscreen',
#  'workitem',
#  'typo3',
#  'node-r',
#  'timezone-offset',
#  'cortex-m',
#  'dendrogram',
#  'dns',
#  'autocad-plugin',
#  'event-stor',
#  'codeceptj',
#  'acfpro',
#  'jspdf',
#  'epol',
#  'xcode',
#  'uwp-xaml',
#  'popupmenu',
#  'avx',
#  'semaphor',
#  'celeri',
#  'osx-lion',
#  'texture-map',
#  'model',
#  'pyfmi',
#  'pug',
#  'choropleth',
#  'geojson',
#  'symfony-flex',
#  'tensorflow2.0',
#  'shadow-dom',
#  'apache-commons-fileupload',
#  'hdf',
#  'coq',
#  'scala',
#  'cisco-axl',
#  'nsurlconnect',
#  'bloc',
#  'erlang',
#  'comparison-oper',
#  'enum',
#  'laravel-5.8',
#  'dynamic-type-featur',
#  'oneplus7',
#  'ambient',
#  'method-refer',
#  'joomla',
#  'admin',
#  'associative-array',
#  'google-contacts-api',
#  'jquery-ui-datepick',
#  'libxl',
#  'real-tim',
#  'wifi',
#  'electron-build',
#  'powerapp',
#  'plaid',
#  'odoo-13',
#  'cdo.messag',
#  'tiff',
#  'rtem',
#  'bokeh',
#  'cube',
#  'forfil',
#  'mse',
#  'pagespe',
#  'opengl',
#  'azure-cli2',
#  'roslyn',
#  'http-patch',
#  'amazon-elastic-beanstalk',
#  'encoder-decod',
#  'schedul',
#  'webpack-dev-serv',
#  'section',
#  'angular2-rout',
#  'graphql-j',
#  '3dtouch',
#  'gmail',
#  'media-queri',
#  'delphi-2007',
#  'coldfusion-11',
#  'printf',
#  'nvcc',
#  'zpl',
#  'knapsack-problem',
#  'libsodium',
#  'python-import',
#  'variabl',
#  'c-preprocessor',
#  'data-entri',
#  'azure-application-gateway',
#  'liquibase-hibern',
#  'kustom',
#  'tinymc',
#  'databas',
#  'vb6',
#  'tensorflow-hub',
#  'codec',
#  'opensus',
#  'codepen',
#  'spring-batch-admin',
#  'hl7-fhir',
#  'vue-chartj',
#  'binari',
#  'spring-io',
#  'angular-cli-v6',
#  'mongodb-compass',
#  'arkit',
#  'android-menu',
#  'structured-text',
#  'docker',
#  'timestamp',
#  'angular-servic',
#  'model-check',
#  'macos-mojav',
#  'anpr',
#  'dronekit',
#  'razor-pag',
#  'information-retriev',
#  'spring-react',
#  'reactor-netti',
#  'firefox-developer-tool',
#  'phonegap-plugin',
#  'large-titl',
#  'alpr',
#  'vstest.console.ex',
#  'resourc',
#  'flyout',
#  'ms-access-form',
#  'file-not-found',
#  'kapt',
#  'aws-farg',
#  'google-cloud-iam',
#  'microsoft-team',
#  'font-awesom',
#  'autocompletetextview',
#  'executable-jar',
#  'fabric-beta',
#  'iar',
#  'mmap',
#  'jsf-2.3',
#  'trojan',
#  'concurr',
#  'azure-app-service-plan',
#  'authorize-attribut',
#  'rider',
#  'node.j',
#  'wash-out',
#  'soap-client',
#  'asp.net-core-rout',
#  'report',
#  'intun',
#  'sbcl',
#  'partit',
#  'web',
#  'javascript',
#  'openalpr',
#  'tabul',
#  'tpl-dataflow',
#  'pyodbc',
#  'ipc',
#  'ifttt',
#  'lodash',
#  'doctest',
#  'swiftui-list',
#  'xamarin.forms.shel',
#  'php-5.6',
#  'ad',
#  'google-cloud-firestor',
#  'jquerydatetimepick',
#  'sampl',
#  'sqoop',
#  'winsock',
#  'google-oauth2',
#  'multi-select',
#  'firefox',
#  'cart',
#  'sip',
#  'tensorflow.j',
#  'strtok',
#  'r-plot',
#  'except',
#  'flexbox',
#  'grafana-alert',
#  'angular9',
#  'dovecot',
#  'wsh',
#  'openmpi',
#  'spring-data-jpa',
#  'bz2',
#  'sed',
#  'pymel',
#  'eel',
#  'google-drive-pick',
#  'gridsearchcv',
#  'caliburn.micro',
#  'recurs',
#  'avd',
#  'simplesamlphp',
#  'branch',
#  'jsdoc',
#  'android-safe-arg',
#  'fold-express',
#  'firefox-o',
#  'visual-studio-app-cent',
#  'azure-ad-domain-servic',
#  'hyperthread',
#  'react-prop',
#  'compiler-construct',
#  'implicit',
#  'knowledge-graph',
#  'bookmarklet',
#  'scene',
#  'mixture-model',
#  'scala-gatl',
#  'multiprocess',
#  'arrow-kt',
#  'appstore-approv',
#  'persistent-memori',
#  'fault-toler',
#  'quantitative-fin',
#  'spring-secur',
#  'smartcontract',
#  'asp.net-ident',
#  'azure-monitor',
#  'bootstrap-datepick',
#  'nested-list',
#  'passphras',
#  'jointj',
#  'concurrent.futur',
#  'mstest',
#  'pacman-package-manag',
#  'hasura',
#  'mac-app-stor',
#  'uisearchcontrol',
#  'criteria',
#  'reinforcement-learn',
#  'cross-compil',
#  'owl-carousel',
#  'angular-pip',
#  'forum',
#  'visual-studio-debug',
#  'undefined-behavior',
#  'pivottable.j',
#  'xtragrid',
#  'maven-plugin',
#  'dataload',
#  'google-apps-script-addon',
#  'push',
#  'windows-authent',
#  'micronaut-data',
#  'micromet',
#  'memorystream',
#  'core-j',
#  'awk',
#  'w3wp',
#  'monday.com',
#  'jpanel',
#  'kibana',
#  'http-status-code-403',
#  'json-view',
#  'babylonj',
#  'xilinx',
#  'azure-virtual-machin',
#  'nsmanagedobject',
#  'datetime-format',
#  'x86',
#  'type-mismatch',
#  'ratchet',
#  'substr',
#  'sql-server',
#  'git-tf',
#  'continuous-deploy',
#  'object-lifetim',
#  'angular-direct',
#  'textinput',
#  'fileinputstream',
#  'race-condit',
#  'navicat',
#  'traceback',
#  'slider',
#  'low-lat',
#  'setjmp',
#  'comment',
#  'react-router-dom',
#  'axon',
#  'delphi-xe7',
#  'laravel-ui',
#  'logical-oper',
#  'vuetify.j',
#  'ghostscript',
#  'extent',
#  'metalkit',
#  'getter-sett',
#  'beautifulsoup',
#  'laravel-echo',
#  'batch-process',
#  'android-application-class',
#  'spring-data-r2dbc',
#  'google-login',
#  'aws-sdk',
#  'equality-oper',
#  'antd',
#  'r-markdown',
#  'debezium',
#  'dart-pub',
#  'vcl',
#  'twitter-oauth',
#  'stub',
#  'share',
#  'laravel-4',
#  'netbeans-8',
#  'keystor',
#  'var',
#  'spring-webcli',
#  'futur',
#  'rgb',
#  'android-frag',
#  'cannot-find-symbol',
#  'imagepick',
#  'json-deseri',
#  'multidimensional-array',
#  'react-compon',
#  'window-funct',
#  'application.properti',
#  'samsung-smart-tv',
#  'openurl',
#  'shellcheck',
#  'sf-symbol',
#  'virtualenvwrapp',
#  'unpivot',
#  'google-app-engine-python',
#  'spidermonkey',
#  'alexa',
#  'paypal-subscript',
#  'image-registr',
#  'vps',
#  'formarray',
#  'tinytex',
#  'data-mask',
#  'keyboard-input',
#  'nodemcu',
#  'amazon-athena',
#  'openid-connect',
#  'cllocationmanag',
#  'requirements.txt',
#  'cardview',
#  'clipboard',
#  'object-fit',
#  'php-7.3',
#  'prim',
#  'azure-pipelines-release-pipelin',
#  'dhcp',
#  'phpstorm',
#  'jboss-eap-6',
#  'google-admin-sdk',
#  'coordinator-layout',
#  'uitableview',
#  'icc',
#  'vue-rout',
#  'hough-transform',
#  'novnc',
#  'style',
#  'kendo-schedul',
#  'file-io',
#  'testng',
#  'android-room-rel',
#  'activerecord',
#  'solid',
#  'provid',
#  'nashorn',
#  'audiokit',
#  'string-liter',
#  'android-debug',
#  'shoretel',
#  'complet',
#  'xlsx',
#  'button',
#  'masm',
#  'opus',
#  'hotjar',
#  'firebase-host',
#  'checkbox',
#  'django-admin',
#  'azure-c',
#  'cakephp-3.7',
#  'powerqueri',
#  'large-data',
#  'injected-class-nam',
#  'aws-glue-data-catalog',
#  'pinvok',
#  'std',
#  'spring-aop',
#  'zos',
#  'nullabl',
#  'tab',
#  'type-graphql',
#  'inputmismatchexcept',
#  'buildroot',
#  'timedelta',
#  'applet',
#  'png',
#  'azure-managed-ident',
#  'vbscript',
#  'integ',
#  'escap',
#  'google-form',
#  'connect-direct',
#  'rspec-rail',
#  'crashlyt',
#  'stan',
#  'gurobi',
#  'azure-batch',
#  'rxalamofir',
#  'convolut',
#  'nose',
#  'hotspot',
#  'labview',
#  'import',
#  'centos7',
#  'spark-hiv',
#  'kuyruk',
#  'destructor',
#  'hexo',
#  'database-trigg',
#  'purrr',
#  'nuxt.j',
#  'json',
#  'masstransit',
#  'spring-reactor',
#  'lotusscript',
#  'emacspeak',
#  'sight',
#  'activity-lifecycl',
#  'control',
#  'pbkdf2',
#  'youtube-iframe-api',
#  'netty-socketio',
#  'lightgbm',
#  'option',
#  'maven-release-plugin',
#  'serv',
#  'dataset',
#  'jsch',
#  'textfield',
#  'sse',
#  'stata',
#  'spring-batch',
#  'accordion',
#  'ocsp',
#  'downloadfil',
#  'keycloak-gatekeep',
#  'http-status-code-500',
#  'azure-management-api',
#  'soapui',
#  'unique-constraint',
#  'stat',
#  'pyqt',
#  'scrum',
#  'fleet',
#  'jce',
#  'logistic-regress',
#  'reactor',
#  'thumbnail',
#  'mscorlib',
#  'move-constructor',
#  'modelmapp',
#  'connector',
#  'sql-server-data-tool',
#  'vmware-workst',
#  'llvm',
#  'babel-polyfil',
#  'backbone.j',
#  'android-bundl',
#  'dynamics-crm-365',
#  'webpack-load',
#  'cloudfoundri',
#  'immut',
#  'mat',
#  'leakcanari',
#  'orm',
#  'geopanda',
#  'code-reus',
#  'actionview',
#  'react-navig',
#  'graphql-java',
#  'metadata',
#  'dbi',
#  'scanf',
#  'queue',
#  'google-tag-manag',
#  'xamarin.android',
#  'gazebo-simu',
#  'webview',
#  'spring-cloud-gateway',
#  'google-text-to-speech',
#  'uidocumentpickervc',
#  'github',
#  'sugarcrm',
#  'ui-autom',
#  'kubernet',
#  'imput',
#  'shopifi',
#  'align',
#  'falcon',
#  'coinbase-api',
#  'elementor',
#  'jquery-file-upload',
#  'xampp',
#  'webpack-file-load',
#  'amazon-appstor',
#  'redux-thunk',
#  'jupyter-lab',
#  'winston',
#  'firebase-mlkit',
#  'dolphindb',
#  'constexpr',
#  'cert-manag',
#  'gcov',
#  'azure-notificationhub',
#  'local',
#  'line-numb',
#  'heatmap',
#  'ecdh',
#  'peoplesoft',
#  'data-convers',
#  'bracket',
#  'navbar',
#  'sal',
#  'vaadin14',
#  'scala-java-interop',
#  'pandas-groupbi',
#  'runtim',
#  'github-app',
#  'entity-framework-plus',
#  'unicode-str',
#  'thread-abort',
#  'vue.j',
#  'avspeechsynthes',
#  'npgsql',
#  'autoregressive-model',
#  'stop-word',
#  'avaudioengin',
#  'row-level-secur',
#  'google-classroom',
#  'rust-tokio',
#  'aws-app-mesh',
#  'tensorflow-feder',
#  'flutter-anim',
#  'pyppet',
#  'hashtabl',
#  'swift',
#  'pulp',
#  'http',
#  'arduino',
#  'google-calendar-api',
#  'qlikview',
#  'aspectj',
#  'dynamics-365-oper',
#  'in-memory-databas',
#  'sdl',
#  'payment-gateway',
#  'module-map',
#  'couchbas',
#  'bqplot',
#  'postgresql-11',
#  'sublimetext3',
#  'pygraphviz',
#  'bean-valid',
#  'sprite',
#  'rlang',
#  'reactj',
#  'facebook-javascript-sdk',
#  'temporary-fil',
#  'pypdf2',
#  'mpeg2-t',
#  'google-maps-api-3',
#  'session',
#  'serial-commun',
#  'large-fil',
#  'nvidia-dock',
#  'format',
#  'draggabl',
#  'browser-link',
#  'google-cloud-monitor',
#  'android-volley',
#  'aws-iot',
#  'firebase-cloud-messag',
#  'ras',
#  'video-captur',
#  'angular7',
#  'file-descriptor',
#  'symfony-3.4',
#  'moodle-api',
#  'octav',
#  'mod-wsgi',
#  'objective-c',
#  'sld',
#  'realm',
#  'tikz',
#  'android-tv',
#  'apache-calcit',
#  'react-redux',
#  'eventhandl',
#  'linq-to-ent',
#  'node-mocks-http',
#  'mono',
#  'updat',
#  'alphabet',
#  'firebase-authent',
#  'folium',
#  'pm2',
#  'amazon-cloudfront',
#  'dtype',
#  'pepper',
#  'rabbitmqctl',
#  'persistent-volum',
#  'telegram',
#  'hotkey',
#  'zoo',
#  'outer-join',
#  'xamarin.essenti',
#  'xiaomi',
#  'command-line-interfac',
#  'image-process',
#  'animate.css',
#  'lottie-io',
#  'property-wrapp',
#  'regex-dos-attack',
#  'auth0',
#  'anagram',
#  'google-iam',
#  'swiftyuserdefault',
#  'control-m',
#  'ansible-awx',
#  'polym',
#  'distutil',
#  'session-cooki',
#  'sitecor',
#  'tcxgrid',
#  'complexity-theori',
#  'google-cloud-endpoint',
#  'tpu',
#  'faster-rcnn',
#  'babelj',
#  'retina-display',
#  'dicom',
#  'autofil',
#  'myfac',
#  'google-analyt',
#  'asp.net-mvc-4',
#  'ptc-windchil',
#  'pass-by-nam',
#  'mpiexec',
#  'codenameon',
#  'camera-calibr',
#  'nullpointerexcept',
#  'singularity-contain',
#  'facet-grid',
#  'inertia',
#  'ios10.3',
#  'x509certificate2',
#  'reactive-form',
#  'ls-remot',
#  'pentaho-data-integr',
#  'includ',
#  'tortoisesvn',
#  'pexpect',
#  'http-proxi',
#  'dplyr',
#  'amazon-mw',
#  'azure-funct',
#  'stack-overflow',
#  'kendo-ui',
#  'progressive-web-app',
#  'linq',
#  'listviewitem',
#  'azure-webapp',
#  'blazor',
#  'gradle-depend',
#  'dockerfil',
#  'rasterio',
#  'apt',
#  'aws-cloudwatch-log-insight',
#  'spark-structured-stream',
#  'grand-central-dispatch',
#  'exuberant-ctag',
#  'google-places-api',
#  'azure-functions-runtim',
#  'android-10.0',
#  'rtx',
#  'full-disk-access',
#  'selenium-firefoxdriv',
#  'cri-o',
#  'vue-composition-api',
#  'python-venv',
#  'sanit',
#  'emplac',
#  'react-virtu',
#  'fhir-net-api',
#  'moviepi',
#  'perf',
#  'window',
#  'nul',
#  'http-header',
#  'variable-assign',
#  'webpack-4',
#  'mockito',
#  ...}

# %%
len(tags_set)
# Out:
# 6249

# %% [markdown]
# # Preprocessing test

# %%
doc_sample = data.loc[3, 'post_body']

print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample))
# Out:
# original document:
# ['<p>I', 'want', 'to', 'install', 'kivy', 'on', 'a', 'pc', 'that', "doesn't", 'have', 'an', 'internet', 'connection,', 'so', 'I', "can't", 'install', 'it', 'using', 'pip.', 'Can', 'someone', 'tell', 'me', 'how', 'to', 'install', 'kivy', 'offline?</p>']
#
#
#  tokenized and lemmatized document:
# ['want', 'instal', 'kivi', 'internet', 'connect', 'instal', 'tell', 'instal', 'kivi', 'offlin']

# %%
processed_docs = data['post_body'].map(preprocess)

# %%
processed_docs[12]
# Out:
# ['function',
#  'data',
#  'firebas',
#  'want',
#  'data',
#  'state',
#  'get',
#  'declar',
#  'array',
#  'push',
#  'data',
#  'setstat',
#  'array',
#  'state',
#  'state',
#  'render',
#  'issu',
#  'work',
#  'perfect',
#  'know',
#  'state',
#  'overr',
#  'data',
#  'item',
#  'logger',
#  'print',
#  'ten',
#  'render',
#  'data',
#  'state',
#  'tell',
#  'json',
#  'valu',
#  'type',
#  'nsnumber',
#  'convert',
#  'nsstring',
#  'avoid',
#  'code',
#  'snippet']

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
dictionary[12]
# Out:
# 'click'

# %%
tfidf = models.TfidfModel(bow_corpus)

# %%
corpus_tfidf = tfidf[bow_corpus]

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=100, id2word=dictionary, passes=2, workers=4)

# %%
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.119*"airflow" + 0.087*"pod" + 0.080*"blank" + 0.055*"ingress" + 0.036*"escap" + 0.035*"cluster" + 0.027*"data" + 0.015*"html" + 0.008*"method" + 0.008*"password"
# Topic: 1 Word: 0.038*"file" + 0.030*"build" + 0.028*"open" + 0.028*"upload" + 0.027*"result" + 0.024*"need" + 0.019*"read" + 0.018*"abl" + 0.018*"know" + 0.016*"perform"
# Topic: 2 Word: 0.124*"output" + 0.054*"command" + 0.041*"understand" + 0.038*"look" + 0.036*"tell" + 0.030*"respons" + 0.027*"boolean" + 0.027*"drive" + 0.024*"clear" + 0.021*"error"
# Topic: 3 Word: 0.117*"archiv" + 0.050*"disk" + 0.050*"temp" + 0.014*"store" + 0.009*"imag" + 0.005*"data" + 0.005*"command" + 0.005*"script" + 0.005*"file" + 0.005*"program"
# Topic: 4 Word: 0.172*"statement" + 0.075*"locat" + 0.066*"center" + 0.051*"bearer" + 0.039*"definit" + 0.026*"evalu" + 0.021*"driver" + 0.019*"hardwar" + 0.019*"window" + 0.017*"optim"
# Topic: 5 Word: 0.140*"static" + 0.139*"databas" + 0.081*"tabl" + 0.076*"curl" + 0.027*"destin" + 0.018*"measur" + 0.012*"librari" + 0.011*"deploy" + 0.011*"creat" + 0.009*"publish"
# Topic: 6 Word: 0.142*"group" + 0.090*"frame" + 0.080*"releas" + 0.079*"sourc" + 0.060*"tomcat" + 0.053*"apach" + 0.044*"nginx" + 0.040*"data" + 0.023*"host" + 0.021*"server"
# Topic: 7 Word: 0.168*"valu" + 0.108*"column" + 0.041*"function" + 0.033*"check" + 0.031*"call" + 0.029*"condit" + 0.022*"step" + 0.021*"black" + 0.020*"rang" + 0.020*"expect"
# Topic: 8 Word: 0.131*"send" + 0.096*"messag" + 0.051*"local" + 0.043*"servic" + 0.032*"endpoint" + 0.031*"correct" + 0.031*"char" + 0.030*"encod" + 0.029*"topic" + 0.027*"context"
# Topic: 9 Word: 0.176*"kafka" + 0.133*"publish" + 0.122*"behavior" + 0.072*"idl" + 0.057*"minut" + 0.009*"bring" + 0.005*"test" + 0.005*"devic" + 0.004*"mode" + 0.003*"produc"
# Topic: 10 Word: 0.064*"space" + 0.064*"address" + 0.041*"copi" + 0.041*"linux" + 0.038*"anim" + 0.037*"data" + 0.036*"zero" + 0.036*"extern" + 0.035*"algorithm" + 0.033*"height"
# Topic: 11 Word: 0.041*"test" + 0.034*"spring" + 0.030*"applic" + 0.029*"icon" + 0.028*"insert" + 0.026*"develop" + 0.024*"graph" + 0.024*"case" + 0.024*"product" + 0.022*"paramet"
# Topic: 12 Word: 0.079*"properti" + 0.073*"valid" + 0.061*"screen" + 0.034*"appl" + 0.033*"tensorflow" + 0.032*"user" + 0.031*"permiss" + 0.026*"picker" + 0.023*"white" + 0.022*"reproduc"
# Topic: 13 Word: 0.181*"maven" + 0.093*"pixel" + 0.054*"initi" + 0.048*"comment" + 0.039*"imag" + 0.033*"audio" + 0.025*"await" + 0.017*"default" + 0.015*"rule" + 0.011*"set"
# Topic: 14 Word: 0.201*"disabl" + 0.058*"conflict" + 0.052*"definit" + 0.037*"locat" + 0.035*"auto" + 0.020*"latest" + 0.019*"creator" + 0.013*"window" + 0.013*"warn" + 0.010*"clone"
# Topic: 15 Word: 0.115*"timestamp" + 0.108*"signatur" + 0.103*"yaml" + 0.028*"plain" + 0.015*"sign" + 0.012*"secur" + 0.006*"request" + 0.006*"header" + 0.005*"rout" + 0.005*"dashboard"
# Topic: 16 Word: 0.133*"bean" + 0.097*"factori" + 0.013*"class" + 0.010*"load" + 0.010*"error" + 0.007*"nest" + 0.006*"copi" + 0.005*"implement" + 0.005*"context" + 0.005*"file"
# Topic: 17 Word: 0.075*"scroll" + 0.061*"navig" + 0.060*"show" + 0.034*"devop" + 0.034*"background" + 0.029*"reach" + 0.028*"listen" + 0.028*"split" + 0.027*"avoid" + 0.026*"view"
# Topic: 18 Word: 0.054*"like" + 0.046*"html" + 0.044*"index" + 0.041*"javascript" + 0.032*"function" + 0.030*"explain" + 0.027*"react" + 0.026*"uniti" + 0.026*"want" + 0.025*"order"
# Topic: 19 Word: 0.029*"guy" + 0.007*"configur" + 0.006*"discuss" + 0.006*"line" + 0.005*"give" + 0.005*"respect" + 0.005*"easi" + 0.005*"anybodi" + 0.005*"matter" + 0.005*"extract"
# Topic: 20 Word: 0.054*"data" + 0.040*"search" + 0.034*"filter" + 0.028*"appreci" + 0.027*"tri" + 0.024*"materi" + 0.024*"function" + 0.023*"great" + 0.023*"help" + 0.023*"thank"
# Topic: 21 Word: 0.164*"photo" + 0.030*"imag" + 0.021*"databas" + 0.020*"mysql" + 0.006*"save" + 0.005*"contain" + 0.005*"result" + 0.005*"call" + 0.005*"lose" + 0.005*"queri"
# Topic: 22 Word: 0.001*"analyz" + 0.001*"reactj" + 0.001*"schema" + 0.001*"social" + 0.001*"touch" + 0.001*"facebook" + 0.001*"classifi" + 0.001*"checkbox" + 0.001*"box" + 0.001*"cast"
# Topic: 23 Word: 0.001*"analyz" + 0.001*"reactj" + 0.001*"schema" + 0.001*"social" + 0.001*"touch" + 0.001*"facebook" + 0.001*"classifi" + 0.001*"checkbox" + 0.001*"box" + 0.001*"cast"
# Topic: 24 Word: 0.350*"layer" + 0.014*"encod" + 0.014*"neural" + 0.009*"state" + 0.005*"guid" + 0.005*"happen" + 0.003*"simpl" + 0.003*"tensorflow" + 0.003*"tell" + 0.003*"decod"
# Topic: 25 Word: 0.077*"variabl" + 0.071*"docker" + 0.055*"cloud" + 0.055*"port" + 0.050*"access" + 0.049*"contain" + 0.044*"compos" + 0.039*"gateway" + 0.036*"implement" + 0.028*"run"
# Topic: 26 Word: 0.193*"reactiv" + 0.113*"equival" + 0.006*"limit" + 0.006*"rate" + 0.003*"love" + 0.003*"http" + 0.002*"wast" + 0.002*"block" + 0.002*"process" + 0.002*"thread"
# Topic: 27 Word: 0.135*"enter" + 0.125*"sheet" + 0.054*"privat" + 0.052*"shell" + 0.046*"cancel" + 0.043*"accomplish" + 0.033*"workbook" + 0.026*"openssl" + 0.024*"separ" + 0.015*"name"
# Topic: 28 Word: 0.149*"machin" + 0.085*"chunk" + 0.052*"imgur" + 0.037*"wrapper" + 0.020*"variant" + 0.010*"https" + 0.009*"folder" + 0.008*"leav" + 0.007*"element" + 0.006*"simpli"
# Topic: 29 Word: 0.344*"task" + 0.236*"directori" + 0.007*"execut" + 0.007*"root" + 0.004*"infrastructur" + 0.004*"handler" + 0.002*"file" + 0.002*"look" + 0.002*"extens" + 0.001*"hierarchi"
# Topic: 30 Word: 0.001*"analyz" + 0.001*"reactj" + 0.001*"schema" + 0.001*"social" + 0.001*"touch" + 0.001*"facebook" + 0.001*"classifi" + 0.001*"checkbox" + 0.001*"box" + 0.001*"cast"
# Topic: 31 Word: 0.001*"analyz" + 0.001*"reactj" + 0.001*"schema" + 0.001*"social" + 0.001*"touch" + 0.001*"facebook" + 0.001*"classifi" + 0.001*"checkbox" + 0.001*"box" + 0.001*"cast"
# Topic: 32 Word: 0.188*"react" + 0.150*"render" + 0.058*"infer" + 0.049*"patch" + 0.019*"model" + 0.012*"convers" + 0.007*"convert" + 0.006*"content" + 0.006*"normal" + 0.004*"batch"
# Topic: 33 Word: 0.283*"rout" + 0.209*"lambda" + 0.070*"subnet" + 0.045*"associ" + 0.018*"request" + 0.016*"localhost" + 0.007*"server" + 0.006*"endpoint" + 0.003*"articl" + 0.002*"account"
# Topic: 34 Word: 0.048*"string" + 0.045*"element" + 0.029*"loop" + 0.028*"field" + 0.024*"content" + 0.021*"delet" + 0.020*"exampl" + 0.018*"look" + 0.016*"creat" + 0.016*"kind"
# Topic: 35 Word: 0.021*"html" + 0.019*"tabl" + 0.009*"get" + 0.008*"generic" + 0.006*"data" + 0.005*"kinda" + 0.004*"slight" + 0.004*"json" + 0.004*"hit" + 0.004*"popul"
# Topic: 36 Word: 0.122*"instal" + 0.060*"tool" + 0.059*"window" + 0.057*"control" + 0.056*"header" + 0.038*"mode" + 0.033*"guid" + 0.029*"option" + 0.024*"boot" + 0.021*"haven"
# Topic: 37 Word: 0.165*"standard" + 0.029*"kera" + 0.028*"independ" + 0.020*"optim" + 0.009*"predict" + 0.006*"train" + 0.006*"implement" + 0.006*"constant" + 0.005*"claim" + 0.004*"dispatch"
# Topic: 38 Word: 0.151*"mutat" + 0.107*"cycl" + 0.033*"concern" + 0.007*"path" + 0.006*"cordova" + 0.006*"plugin" + 0.005*"frontend" + 0.005*"token" + 0.005*"public" + 0.004*"user"
# Topic: 39 Word: 0.233*"remot" + 0.086*"inherit" + 0.043*"init" + 0.022*"servic" + 0.018*"class" + 0.013*"argument" + 0.012*"need" + 0.011*"constructor" + 0.010*"earli" + 0.006*"object"
# Topic: 40 Word: 0.073*"instruct" + 0.071*"run" + 0.052*"processor" + 0.045*"code" + 0.044*"mention" + 0.041*"line" + 0.035*"recogn" + 0.034*"start" + 0.030*"boot" + 0.028*"track"
# Topic: 41 Word: 0.067*"custom" + 0.038*"argument" + 0.034*"applic" + 0.034*"person" + 0.032*"year" + 0.031*"pass" + 0.025*"phone" + 0.024*"folder" + 0.024*"draw" + 0.023*"comput"
# Topic: 42 Word: 0.004*"sudo" + 0.003*"password" + 0.002*"account" + 0.002*"user" + 0.002*"http" + 0.002*"exec" + 0.002*"conf" + 0.002*"sake" + 0.002*"inform" + 0.002*"config"
# Topic: 43 Word: 0.001*"analyz" + 0.001*"reactj" + 0.001*"schema" + 0.001*"social" + 0.001*"touch" + 0.001*"facebook" + 0.001*"classifi" + 0.001*"checkbox" + 0.001*"box" + 0.001*"cast"
# Topic: 44 Word: 0.093*"imag" + 0.067*"googl" + 0.053*"android" + 0.052*"download" + 0.046*"gradl" + 0.042*"stream" + 0.031*"import" + 0.026*"error" + 0.025*"edit" + 0.022*"rail"
# Topic: 45 Word: 0.088*"size" + 0.080*"save" + 0.060*"write" + 0.050*"file" + 0.041*"possibl" + 0.037*"larg" + 0.035*"binari" + 0.027*"simul" + 0.027*"float" + 0.026*"python"
# Topic: 46 Word: 0.208*"node" + 0.018*"schema" + 0.013*"receiv" + 0.005*"bodi" + 0.004*"pipelin" + 0.004*"record" + 0.004*"messag" + 0.003*"incorpor" + 0.003*"poll" + 0.003*"basi"
# Topic: 47 Word: 0.043*"give" + 0.037*"cell" + 0.033*"answer" + 0.026*"come" + 0.026*"swift" + 0.025*"caus" + 0.024*"memori" + 0.024*"help" + 0.022*"push" + 0.022*"ask"
# Topic: 48 Word: 0.110*"client" + 0.070*"null" + 0.041*"basic" + 0.037*"refresh" + 0.035*"consum" + 0.035*"templat" + 0.033*"blazor" + 0.031*"turn" + 0.029*"creat" + 0.028*"call"
# Topic: 49 Word: 0.171*"plot" + 0.102*"dataset" + 0.082*"ansibl" + 0.064*"hash" + 0.046*"axi" + 0.028*"folder" + 0.017*"horizont" + 0.016*"default" + 0.016*"valu" + 0.012*"line"
# Topic: 50 Word: 0.011*"redirect" + 0.009*"login" + 0.008*"captur" + 0.008*"credenti" + 0.007*"regist" + 0.006*"event" + 0.006*"angular" + 0.006*"applic" + 0.005*"trust" + 0.005*"guard"
# Topic: 51 Word: 0.049*"deploy" + 0.036*"code" + 0.030*"certif" + 0.026*"requir" + 0.021*"kubernet" + 0.020*"increas" + 0.019*"reason" + 0.018*"cluster" + 0.018*"setup" + 0.018*"follow"
# Topic: 52 Word: 0.074*"script" + 0.053*"execut" + 0.050*"want" + 0.043*"generat" + 0.041*"command" + 0.036*"advanc" + 0.034*"attempt" + 0.030*"databas" + 0.027*"thank" + 0.027*"follow"
# Topic: 53 Word: 0.230*"input" + 0.138*"format" + 0.118*"storag" + 0.037*"pars" + 0.032*"bucket" + 0.021*"output" + 0.016*"string" + 0.015*"program" + 0.015*"idea" + 0.010*"problem"
# Topic: 54 Word: 0.001*"analyz" + 0.001*"reactj" + 0.001*"schema" + 0.001*"social" + 0.001*"touch" + 0.001*"facebook" + 0.001*"classifi" + 0.001*"checkbox" + 0.001*"box" + 0.001*"cast"
# Topic: 55 Word: 0.112*"tabl" + 0.072*"row" + 0.046*"tutori" + 0.044*"hour" + 0.027*"ajax" + 0.026*"time" + 0.026*"rule" + 0.024*"expect" + 0.019*"histori" + 0.016*"solut"
# Topic: 56 Word: 0.130*"blur" + 0.122*"mask" + 0.100*"alloc" + 0.004*"perform" + 0.004*"kernel" + 0.003*"devic" + 0.003*"layer" + 0.003*"pictur" + 0.003*"draw" + 0.003*"appli"
# Topic: 57 Word: 0.074*"view" + 0.062*"request" + 0.044*"azur" + 0.041*"provid" + 0.037*"server" + 0.029*"manag" + 0.028*"model" + 0.028*"oper" + 0.028*"achiev" + 0.024*"https"
# Topic: 58 Word: 0.247*"vscode" + 0.132*"arrow" + 0.019*"outdat" + 0.017*"standard" + 0.011*"document" + 0.010*"issu" + 0.010*"elimin" + 0.008*"variabl" + 0.007*"debug" + 0.007*"https"
# Topic: 59 Word: 0.126*"array" + 0.099*"packag" + 0.044*"extens" + 0.044*"share" + 0.043*"log" + 0.039*"refer" + 0.038*"microsoft" + 0.028*"regex" + 0.028*"assembl" + 0.027*"nuget"
# Topic: 60 Word: 0.097*"predict" + 0.088*"kera" + 0.083*"train" + 0.078*"model" + 0.043*"tabl" + 0.043*"behaviour" + 0.038*"sequenc" + 0.033*"metric" + 0.032*"reset" + 0.030*"demo"
# Topic: 61 Word: 0.279*"form" + 0.088*"jqueri" + 0.044*"onclick" + 0.042*"synchron" + 0.025*"ajax" + 0.010*"html" + 0.010*"googl" + 0.008*"model" + 0.007*"post" + 0.007*"edit"
# Topic: 62 Word: 0.126*"compil" + 0.070*"cmake" + 0.065*"length" + 0.047*"pivot" + 0.038*"claim" + 0.037*"appear" + 0.025*"websit" + 0.022*"bar" + 0.019*"node_modul" + 0.017*"decim"
# Topic: 63 Word: 0.179*"scale" + 0.089*"communic" + 0.008*"serial" + 0.007*"frame" + 0.006*"program" + 0.005*"receiv" + 0.004*"port" + 0.003*"softwar" + 0.003*"minut" + 0.003*"face"
# Topic: 64 Word: 0.199*"firestor" + 0.096*"submit" + 0.012*"struggl" + 0.008*"reduc" + 0.007*"today" + 0.006*"updat" + 0.005*"syntax" + 0.005*"dispatch" + 0.005*"wrong" + 0.004*"succeed"
# Topic: 65 Word: 0.001*"analyz" + 0.001*"reactj" + 0.001*"schema" + 0.001*"social" + 0.001*"touch" + 0.001*"facebook" + 0.001*"classifi" + 0.001*"checkbox" + 0.001*"box" + 0.001*"cast"
# Topic: 66 Word: 0.142*"python" + 0.083*"environ" + 0.053*"virtual" + 0.041*"catalina" + 0.040*"maco" + 0.033*"ionic" + 0.025*"error" + 0.023*"instal" + 0.023*"entri" + 0.022*"conda"
# Topic: 67 Word: 0.029*"byte" + 0.008*"output" + 0.004*"file" + 0.004*"miss" + 0.004*"line" + 0.004*"window" + 0.004*"goal" + 0.003*"cach" + 0.003*"write" + 0.003*"test"
# Topic: 68 Word: 0.061*"angular" + 0.048*"type" + 0.044*"undefin" + 0.041*"plugin" + 0.033*"fine" + 0.033*"integr" + 0.025*"typeerror" + 0.023*"method" + 0.021*"player" + 0.020*"consol"
# Topic: 69 Word: 0.218*"xcode" + 0.108*"framework" + 0.048*"docker" + 0.042*"workspac" + 0.027*"build" + 0.018*"folder" + 0.015*"project" + 0.012*"file" + 0.010*"look" + 0.007*"locat"
# Topic: 70 Word: 0.079*"select" + 0.074*"base" + 0.069*"exampl" + 0.047*"multipl" + 0.045*"instanc" + 0.044*"singl" + 0.043*"switch" + 0.043*"simpl" + 0.042*"bootstrap" + 0.038*"dynam"
# Topic: 71 Word: 0.155*"sort" + 0.077*"chrome" + 0.068*"browser" + 0.056*"adapt" + 0.054*"websocket" + 0.052*"ldap" + 0.037*"child" + 0.029*"process" + 0.029*"debug" + 0.020*"mechan"
# Topic: 72 Word: 0.068*"github" + 0.065*"link" + 0.058*"https" + 0.052*"exist" + 0.050*"file" + 0.048*"object" + 0.034*"master" + 0.030*"combin" + 0.029*"section" + 0.024*"blob"
# Topic: 73 Word: 0.131*"node" + 0.119*"regist" + 0.060*"cach" + 0.057*"backend" + 0.053*"react" + 0.051*"mysql" + 0.048*"server" + 0.042*"packet" + 0.028*"connect" + 0.026*"request"
# Topic: 74 Word: 0.133*"swagger" + 0.089*"flask" + 0.008*"secur" + 0.008*"endpoint" + 0.005*"rout" + 0.005*"auth" + 0.004*"token" + 0.003*"usernam" + 0.003*"app" + 0.003*"base"
# Topic: 75 Word: 0.102*"java" + 0.064*"color" + 0.045*"test" + 0.037*"powershel" + 0.035*"thread" + 0.028*"jenkin" + 0.028*"build" + 0.022*"wait" + 0.022*"code" + 0.022*"channel"
# Topic: 76 Word: 0.119*"serial" + 0.082*"longer" + 0.072*"member" + 0.056*"folder" + 0.043*"sound" + 0.032*"inlin" + 0.027*"play" + 0.021*"video" + 0.016*"code" + 0.012*"renam"
# Topic: 77 Word: 0.363*"event" + 0.087*"timer" + 0.061*"dialog" + 0.049*"termin" + 0.045*"loop" + 0.011*"block" + 0.006*"call" + 0.005*"permiss" + 0.004*"handler" + 0.004*"thread"
# Topic: 78 Word: 0.143*"date" + 0.105*"account" + 0.053*"status" + 0.041*"idea" + 0.033*"descript" + 0.028*"close" + 0.026*"pictur" + 0.025*"balanc" + 0.023*"exit" + 0.022*"enum"
# Topic: 79 Word: 0.078*"modul" + 0.072*"nativ" + 0.069*"librari" + 0.056*"devic" + 0.036*"enabl" + 0.034*"android" + 0.029*"couldn" + 0.028*"map" + 0.027*"fail" + 0.026*"support"
# Topic: 80 Word: 0.175*"handler" + 0.152*"overrid" + 0.020*"generic" + 0.016*"handl" + 0.012*"class" + 0.009*"global" + 0.008*"logic" + 0.008*"collect" + 0.007*"want" + 0.007*"know"
# Topic: 81 Word: 0.355*"queri" + 0.072*"tabl" + 0.027*"okay" + 0.016*"data" + 0.013*"order" + 0.010*"databas" + 0.009*"guidanc" + 0.009*"correct" + 0.008*"right" + 0.007*"figur"
# Topic: 82 Word: 0.134*"notebook" + 0.090*"grid" + 0.076*"book" + 0.049*"python" + 0.040*"alpha" + 0.038*"latex" + 0.035*"posit" + 0.031*"variat" + 0.022*"queri" + 0.018*"scenario"
# Topic: 83 Word: 0.044*"class" + 0.032*"differ" + 0.030*"number" + 0.029*"return" + 0.029*"object" + 0.029*"project" + 0.027*"method" + 0.027*"depend" + 0.021*"config" + 0.021*"line"
# Topic: 84 Word: 0.001*"analyz" + 0.001*"reactj" + 0.001*"schema" + 0.001*"social" + 0.001*"touch" + 0.001*"facebook" + 0.001*"classifi" + 0.001*"checkbox" + 0.001*"box" + 0.001*"cast"
# Topic: 85 Word: 0.013*"pair" + 0.012*"speed" + 0.004*"solut" + 0.003*"column" + 0.003*"row" + 0.003*"fall" + 0.003*"chunk" + 0.003*"valu" + 0.003*"data" + 0.003*"vector"
# Topic: 86 Word: 0.040*"json" + 0.026*"follow" + 0.024*"core" + 0.024*"remov" + 0.023*"issu" + 0.022*"work" + 0.021*"creat" + 0.019*"like" + 0.018*"file" + 0.017*"program"
# Topic: 87 Word: 0.073*"compon" + 0.046*"error" + 0.046*"page" + 0.044*"display" + 0.042*"store" + 0.039*"fetch" + 0.035*"state" + 0.035*"throw" + 0.035*"trigger" + 0.033*"react"
# Topic: 88 Word: 0.111*"login" + 0.070*"auth" + 0.069*"http" + 0.057*"email" + 0.053*"bodi" + 0.045*"callback" + 0.040*"session" + 0.035*"return" + 0.030*"prevent" + 0.026*"param"
# Topic: 89 Word: 0.092*"video" + 0.063*"calcul" + 0.051*"express" + 0.039*"numpi" + 0.034*"batch" + 0.028*"youtub" + 0.025*"transform" + 0.024*"watch" + 0.023*"python" + 0.020*"nodej"
# Topic: 90 Word: 0.224*"report" + 0.111*"entiti" + 0.087*"visual" + 0.046*"studio" + 0.027*"affect" + 0.017*"exact" + 0.017*"instal" + 0.014*"templat" + 0.012*"machin" + 0.008*"work"
# Topic: 91 Word: 0.133*"list" + 0.066*"set" + 0.052*"type" + 0.044*"post" + 0.042*"style" + 0.036*"appli" + 0.028*"display" + 0.028*"layout" + 0.028*"checkbox" + 0.027*"page"
# Topic: 92 Word: 0.098*"queri" + 0.014*"mysql" + 0.007*"server" + 0.006*"tabl" + 0.006*"result" + 0.004*"base" + 0.004*"unsur" + 0.003*"except" + 0.003*"object" + 0.003*"custom"
# Topic: 93 Word: 0.092*"memori" + 0.047*"load" + 0.030*"loader" + 0.006*"relev" + 0.005*"debug" + 0.005*"okay" + 0.004*"expect" + 0.002*"kernel" + 0.002*"zero" + 0.002*"command"
# Topic: 94 Word: 0.178*"token" + 0.154*"weight" + 0.052*"stock" + 0.015*"box" + 0.012*"crop" + 0.011*"absolut" + 0.010*"measur" + 0.009*"market" + 0.008*"trust" + 0.007*"differ"
# Topic: 95 Word: 0.207*"xamarin" + 0.007*"directori" + 0.007*"cordova" + 0.007*"develop" + 0.007*"activ" + 0.006*"microsoft" + 0.006*"authent" + 0.004*"azur" + 0.004*"quickstart" + 0.004*"bearer"
# Topic: 96 Word: 0.203*"connect" + 0.057*"unit" + 0.057*"mongodb" + 0.046*"server" + 0.040*"except" + 0.036*"width" + 0.036*"test" + 0.031*"trace" + 0.027*"forward" + 0.026*"driver"
# Topic: 97 Word: 0.110*"print" + 0.057*"charact" + 0.053*"record" + 0.045*"declar" + 0.036*"long" + 0.035*"pipelin" + 0.034*"press" + 0.029*"snippet" + 0.025*"unfortun" + 0.025*"assert"
# Topic: 98 Word: 0.240*"chart" + 0.101*"modal" + 0.058*"mysql" + 0.029*"wordpress" + 0.025*"height" + 0.013*"contract" + 0.012*"display" + 0.012*"show" + 0.010*"load" + 0.009*"page"
# Topic: 99 Word: 0.056*"button" + 0.049*"text" + 0.044*"click" + 0.027*"time" + 0.026*"activ" + 0.026*"convert" + 0.024*"page" + 0.023*"word" + 0.023*"error" + 0.022*"load"

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=100, id2word=dictionary, passes=2, workers=2)

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.021*"work" + 0.017*"error" + 0.014*"command" + 0.014*"project" + 0.014*"tri" + 0.013*"follow" + 0.012*"instal" + 0.012*"code" + 0.011*"https" + 0.011*"like"
# Topic: 1
# Words: 0.029*"tri" + 0.028*"error" + 0.021*"imag" + 0.019*"work" + 0.017*"file" + 0.015*"note" + 0.015*"select" + 0.012*"build" + 0.012*"version" + 0.012*"creat"
# Topic: 2
# Words: 0.034*"grid" + 0.019*"file" + 0.015*"work" + 0.014*"tri" + 0.013*"set" + 0.012*"code" + 0.011*"data" + 0.010*"link" + 0.010*"cell" + 0.010*"follow"
# Topic: 3
# Words: 0.020*"code" + 0.019*"tri" + 0.018*"request" + 0.017*"error" + 0.016*"work" + 0.015*"https" + 0.011*"follow" + 0.010*"azur" + 0.010*"need" + 0.009*"token"
# Topic: 4
# Words: 0.058*"file" + 0.029*"info" + 0.021*"folder" + 0.021*"exampl" + 0.020*"download" + 0.017*"error" + 0.016*"directori" + 0.015*"path" + 0.014*"work" + 0.014*"tri"
# Topic: 5
# Words: 0.052*"work" + 0.021*"error" + 0.019*"code" + 0.011*"request" + 0.011*"file" + 0.009*"tri" + 0.009*"follow" + 0.009*"post" + 0.008*"problem" + 0.007*"help"
# Topic: 6
# Words: 0.026*"layout" + 0.020*"code" + 0.018*"work" + 0.018*"view" + 0.014*"file" + 0.012*"result" + 0.012*"creat" + 0.011*"messag" + 0.011*"tri" + 0.010*"error"
# Topic: 7
# Words: 0.022*"list" + 0.020*"type" + 0.016*"view" + 0.015*"like" + 0.013*"error" + 0.013*"databas" + 0.013*"code" + 0.011*"want" + 0.011*"data" + 0.010*"stream"
# Topic: 8
# Words: 0.016*"string" + 0.016*"list" + 0.016*"tri" + 0.015*"want" + 0.014*"work" + 0.014*"publish" + 0.013*"chang" + 0.013*"icon" + 0.013*"follow" + 0.011*"code"
# Topic: 9
# Words: 0.045*"video" + 0.034*"work" + 0.023*"valu" + 0.022*"code" + 0.017*"column" + 0.016*"tri" + 0.013*"data" + 0.012*"file" + 0.010*"navig" + 0.010*"show"
# Topic: 10
# Words: 0.021*"work" + 0.020*"tri" + 0.016*"code" + 0.014*"like" + 0.014*"function" + 0.012*"want" + 0.009*"script" + 0.009*"multipl" + 0.008*"help" + 0.008*"queri"
# Topic: 11
# Words: 0.045*"function" + 0.023*"valu" + 0.018*"code" + 0.017*"follow" + 0.015*"string" + 0.014*"creat" + 0.013*"tri" + 0.012*"exampl" + 0.012*"input" + 0.012*"need"
# Topic: 12
# Words: 0.018*"file" + 0.016*"perform" + 0.015*"like" + 0.014*"packag" + 0.014*"result" + 0.013*"follow" + 0.013*"code" + 0.013*"batch" + 0.012*"want" + 0.011*"know"
# Topic: 13
# Words: 0.030*"work" + 0.021*"tri" + 0.015*"valid" + 0.015*"error" + 0.014*"string" + 0.014*"code" + 0.013*"show" + 0.011*"view" + 0.009*"valu" + 0.009*"file"
# Topic: 14
# Words: 0.029*"tri" + 0.019*"compos" + 0.018*"instal" + 0.018*"file" + 0.016*"matrix" + 0.014*"differ" + 0.014*"java" + 0.014*"scale" + 0.013*"creat" + 0.012*"limit"
# Topic: 15
# Words: 0.050*"number" + 0.021*"code" + 0.015*"chang" + 0.014*"work" + 0.014*"color" + 0.014*"want" + 0.014*"tri" + 0.013*"button" + 0.013*"digit" + 0.013*"exampl"
# Topic: 16
# Words: 0.021*"work" + 0.020*"group" + 0.018*"imag" + 0.017*"agent" + 0.016*"run" + 0.014*"pipelin" + 0.014*"tri" + 0.013*"error" + 0.012*"rail" + 0.012*"creat"
# Topic: 17
# Words: 0.041*"data" + 0.020*"tri" + 0.017*"work" + 0.016*"code" + 0.015*"like" + 0.014*"time" + 0.013*"frame" + 0.013*"want" + 0.011*"function" + 0.010*"valu"
# Topic: 18
# Words: 0.030*"tri" + 0.029*"file" + 0.025*"error" + 0.023*"time" + 0.020*"get" + 0.018*"datafram" + 0.016*"follow" + 0.016*"replac" + 0.012*"effect" + 0.012*"like"
# Topic: 19
# Words: 0.018*"work" + 0.017*"code" + 0.017*"test" + 0.017*"function" + 0.014*"data" + 0.012*"user" + 0.012*"type" + 0.011*"python" + 0.011*"like" + 0.010*"problem"
# Topic: 20
# Words: 0.026*"connect" + 0.023*"tri" + 0.017*"work" + 0.014*"file" + 0.012*"limit" + 0.011*"function" + 0.010*"error" + 0.009*"server" + 0.009*"https" + 0.009*"know"
# Topic: 21
# Words: 0.032*"error" + 0.023*"test" + 0.020*"class" + 0.018*"tri" + 0.014*"code" + 0.011*"project" + 0.011*"action" + 0.011*"like" + 0.010*"pointer" + 0.010*"work"
# Topic: 22
# Words: 0.032*"file" + 0.018*"want" + 0.017*"observ" + 0.016*"read" + 0.015*"color" + 0.014*"thank" + 0.013*"code" + 0.012*"constant" + 0.012*"refer" + 0.012*"char"
# Topic: 23
# Words: 0.027*"want" + 0.023*"contain" + 0.022*"like" + 0.019*"docker" + 0.014*"type" + 0.013*"possibl" + 0.011*"list" + 0.011*"valu" + 0.011*"exampl" + 0.011*"observ"
# Topic: 24
# Words: 0.016*"servic" + 0.015*"path" + 0.015*"error" + 0.014*"want" + 0.014*"like" + 0.012*"work" + 0.012*"browser" + 0.012*"callback" + 0.010*"data" + 0.010*"applic"
# Topic: 25
# Words: 0.022*"creat" + 0.020*"process" + 0.019*"code" + 0.018*"group" + 0.017*"want" + 0.017*"error" + 0.016*"output" + 0.015*"child" + 0.012*"filter" + 0.012*"need"
# Topic: 26
# Words: 0.028*"data" + 0.023*"send" + 0.019*"databas" + 0.017*"email" + 0.015*"code" + 0.015*"work" + 0.014*"java" + 0.014*"error" + 0.013*"tri" + 0.012*"valu"
# Topic: 27
# Words: 0.034*"error" + 0.025*"file" + 0.023*"code" + 0.019*"follow" + 0.015*"like" + 0.014*"tri" + 0.011*"problem" + 0.011*"warn" + 0.010*"test" + 0.010*"know"
# Topic: 28
# Words: 0.040*"code" + 0.017*"function" + 0.017*"error" + 0.017*"like" + 0.016*"follow" + 0.015*"work" + 0.010*"tri" + 0.010*"want" + 0.010*"file" + 0.009*"chang"
# Topic: 29
# Words: 0.090*"java" + 0.024*"apach" + 0.023*"file" + 0.016*"tri" + 0.014*"servic" + 0.012*"work" + 0.011*"invok" + 0.011*"core" + 0.010*"log" + 0.010*"error"
# Topic: 30
# Words: 0.050*"file" + 0.028*"error" + 0.027*"tensorflow" + 0.026*"local" + 0.020*"cuda" + 0.019*"tri" + 0.017*"devic" + 0.014*"open" + 0.013*"default" + 0.013*"librari"
# Topic: 31
# Words: 0.028*"tri" + 0.023*"button" + 0.023*"want" + 0.015*"code" + 0.015*"valu" + 0.014*"like" + 0.014*"event" + 0.013*"user" + 0.012*"work" + 0.011*"click"
# Topic: 32
# Words: 0.036*"form" + 0.018*"work" + 0.015*"want" + 0.015*"list" + 0.014*"memori" + 0.013*"object" + 0.013*"tri" + 0.012*"case" + 0.012*"thread" + 0.011*"page"
# Topic: 33
# Words: 0.029*"error" + 0.017*"work" + 0.017*"follow" + 0.016*"field" + 0.015*"tabl" + 0.014*"creat" + 0.014*"code" + 0.012*"account" + 0.011*"issu" + 0.011*"file"
# Topic: 34
# Words: 0.036*"notif" + 0.020*"work" + 0.019*"send" + 0.016*"push" + 0.015*"page" + 0.012*"type" + 0.011*"firebas" + 0.011*"build" + 0.011*"user" + 0.011*"time"
# Topic: 35
# Words: 0.025*"core" + 0.025*"class" + 0.022*"thread" + 0.021*"project" + 0.019*"like" + 0.015*"work" + 0.014*"code" + 0.013*"file" + 0.012*"creat" + 0.010*"queue"
# Topic: 36
# Words: 0.042*"imag" + 0.020*"tri" + 0.015*"code" + 0.015*"file" + 0.014*"upload" + 0.013*"like" + 0.012*"work" + 0.010*"updat" + 0.010*"chang" + 0.010*"save"
# Topic: 37
# Words: 0.019*"applic" + 0.018*"tri" + 0.017*"data" + 0.016*"like" + 0.015*"file" + 0.015*"code" + 0.012*"work" + 0.011*"follow" + 0.011*"access" + 0.010*"configur"
# Topic: 38
# Words: 0.022*"error" + 0.019*"like" + 0.018*"tri" + 0.016*"time" + 0.014*"creat" + 0.012*"updat" + 0.012*"work" + 0.011*"code" + 0.010*"get" + 0.009*"tabl"
# Topic: 39
# Words: 0.025*"thread" + 0.020*"code" + 0.016*"page" + 0.016*"array" + 0.013*"tri" + 0.011*"work" + 0.010*"applic" + 0.010*"creat" + 0.010*"need" + 0.010*"version"
# Topic: 40
# Words: 0.019*"file" + 0.015*"user" + 0.014*"work" + 0.013*"tri" + 0.013*"connect" + 0.013*"code" + 0.012*"server" + 0.012*"function" + 0.012*"applic" + 0.011*"like"
# Topic: 41
# Words: 0.041*"file" + 0.022*"code" + 0.018*"error" + 0.015*"build" + 0.014*"folder" + 0.013*"tri" + 0.013*"work" + 0.012*"like" + 0.009*"creat" + 0.009*"know"
# Topic: 42
# Words: 0.030*"test" + 0.021*"like" + 0.018*"arrow" + 0.013*"tri" + 0.012*"https" + 0.012*"grpc" + 0.011*"creat" + 0.011*"code" + 0.011*"block" + 0.011*"junit"
# Topic: 43
# Words: 0.036*"task" + 0.029*"queri" + 0.027*"status" + 0.018*"index" + 0.015*"filter" + 0.014*"want" + 0.014*"schedul" + 0.014*"error" + 0.013*"certif" + 0.013*"data"
# Topic: 44
# Words: 0.025*"model" + 0.020*"python" + 0.020*"code" + 0.019*"predict" + 0.016*"train" + 0.015*"display" + 0.014*"tri" + 0.013*"text" + 0.012*"list" + 0.011*"follow"
# Topic: 45
# Words: 0.034*"error" + 0.016*"test" + 0.014*"tri" + 0.013*"follow" + 0.013*"work" + 0.013*"server" + 0.012*"connect" + 0.012*"deploy" + 0.011*"file" + 0.011*"messag"
# Topic: 46
# Words: 0.021*"refer" + 0.018*"tri" + 0.017*"file" + 0.014*"like" + 0.014*"code" + 0.013*"azur" + 0.012*"work" + 0.011*"look" + 0.010*"search" + 0.009*"build"
# Topic: 47
# Words: 0.040*"android" + 0.032*"googl" + 0.019*"error" + 0.019*"valu" + 0.018*"tri" + 0.016*"play" + 0.015*"code" + 0.015*"want" + 0.014*"work" + 0.012*"function"
# Topic: 48
# Words: 0.035*"creat" + 0.030*"file" + 0.020*"project" + 0.013*"error" + 0.012*"method" + 0.012*"set" + 0.012*"command" + 0.011*"task" + 0.011*"react" + 0.009*"node"
# Topic: 49
# Words: 0.069*"test" + 0.032*"compon" + 0.018*"driver" + 0.017*"load" + 0.016*"like" + 0.016*"server" + 0.015*"selenium" + 0.015*"instal" + 0.013*"unit" + 0.013*"version"
# Topic: 50
# Words: 0.036*"error" + 0.032*"tri" + 0.025*"instal" + 0.019*"code" + 0.017*"page" + 0.014*"number" + 0.013*"work" + 0.011*"data" + 0.010*"member" + 0.010*"function"
# Topic: 51
# Words: 0.024*"user" + 0.019*"token" + 0.014*"auth" + 0.011*"work" + 0.011*"file" + 0.011*"mysql" + 0.011*"error" + 0.009*"python" + 0.009*"like" + 0.009*"case"
# Topic: 52
# Words: 0.038*"build" + 0.018*"tri" + 0.017*"trigger" + 0.013*"user" + 0.012*"branch" + 0.012*"messag" + 0.011*"want" + 0.011*"work" + 0.011*"servic" + 0.010*"model"
# Topic: 53
# Words: 0.036*"date" + 0.027*"error" + 0.021*"tri" + 0.016*"packag" + 0.015*"certif" + 0.015*"code" + 0.015*"sign" + 0.014*"server" + 0.014*"instal" + 0.014*"host"
# Topic: 54
# Words: 0.023*"server" + 0.014*"tri" + 0.014*"entiti" + 0.013*"code" + 0.013*"instal" + 0.013*"need" + 0.012*"servic" + 0.011*"want" + 0.011*"java" + 0.010*"error"
# Topic: 55
# Words: 0.029*"like" + 0.021*"work" + 0.016*"user" + 0.015*"input" + 0.014*"tri" + 0.010*"code" + 0.010*"creat" + 0.010*"error" + 0.009*"file" + 0.009*"project"
# Topic: 56
# Words: 0.023*"nativ" + 0.017*"like" + 0.016*"react" + 0.015*"error" + 0.014*"want" + 0.014*"valu" + 0.013*"variabl" + 0.011*"command" + 0.011*"need" + 0.011*"work"
# Topic: 57
# Words: 0.020*"work" + 0.015*"time" + 0.015*"like" + 0.015*"file" + 0.012*"tri" + 0.009*"applic" + 0.009*"valid" + 0.009*"follow" + 0.009*"error" + 0.008*"problem"
# Topic: 58
# Words: 0.043*"select" + 0.032*"code" + 0.030*"valu" + 0.020*"error" + 0.019*"compon" + 0.017*"chang" + 0.012*"dropdown" + 0.012*"want" + 0.011*"function" + 0.011*"tri"
# Topic: 59
# Words: 0.088*"file" + 0.015*"contain" + 0.015*"tri" + 0.015*"read" + 0.014*"error" + 0.014*"write" + 0.013*"docker" + 0.013*"applic" + 0.013*"data" + 0.012*"like"
# Topic: 60
# Words: 0.024*"window" + 0.020*"provid" + 0.019*"program" + 0.017*"code" + 0.017*"error" + 0.016*"instal" + 0.015*"spark" + 0.013*"tri" + 0.012*"microsoft" + 0.012*"work"
# Topic: 61
# Words: 0.033*"code" + 0.025*"tri" + 0.020*"file" + 0.019*"devic" + 0.015*"work" + 0.013*"error" + 0.009*"variabl" + 0.009*"compil" + 0.008*"color" + 0.008*"like"
# Topic: 62
# Words: 0.039*"code" + 0.026*"work" + 0.021*"tri" + 0.016*"follow" + 0.014*"error" + 0.013*"like" + 0.011*"method" + 0.011*"want" + 0.010*"help" + 0.010*"build"
# Topic: 63
# Words: 0.044*"file" + 0.017*"tri" + 0.014*"error" + 0.014*"script" + 0.012*"follow" + 0.011*"work" + 0.010*"code" + 0.010*"like" + 0.009*"differ" + 0.008*"problem"
# Topic: 64
# Words: 0.023*"method" + 0.021*"want" + 0.019*"error" + 0.018*"tri" + 0.017*"class" + 0.015*"work" + 0.012*"file" + 0.011*"function" + 0.011*"code" + 0.011*"like"
# Topic: 65
# Words: 0.020*"tri" + 0.017*"applic" + 0.014*"want" + 0.013*"code" + 0.011*"error" + 0.010*"work" + 0.009*"account" + 0.009*"chang" + 0.008*"node" + 0.008*"symfoni"
# Topic: 66
# Words: 0.018*"user" + 0.018*"editor" + 0.016*"word" + 0.015*"home" + 0.014*"code" + 0.012*"space" + 0.012*"tri" + 0.012*"line" + 0.011*"want" + 0.011*"screen"
# Topic: 67
# Words: 0.047*"build" + 0.028*"project" + 0.026*"gradl" + 0.023*"file" + 0.022*"window" + 0.022*"android" + 0.019*"command" + 0.016*"execut" + 0.015*"error" + 0.015*"fail"
# Topic: 68
# Words: 0.037*"file" + 0.027*"list" + 0.021*"tri" + 0.020*"instal" + 0.015*"work" + 0.012*"error" + 0.012*"delet" + 0.012*"build" + 0.010*"like" + 0.010*"need"
# Topic: 69
# Words: 0.032*"deploy" + 0.020*"build" + 0.014*"follow" + 0.014*"creat" + 0.013*"column" + 0.013*"fragment" + 0.013*"tri" + 0.012*"call" + 0.012*"like" + 0.011*"method"
# Topic: 70
# Words: 0.020*"file" + 0.018*"tri" + 0.017*"code" + 0.016*"test" + 0.015*"time" + 0.015*"start" + 0.014*"problem" + 0.013*"follow" + 0.013*"like" + 0.011*"button"
# Topic: 71
# Words: 0.034*"data" + 0.020*"like" + 0.019*"file" + 0.017*"want" + 0.016*"exampl" + 0.014*"chart" + 0.012*"work" + 0.012*"json" + 0.011*"tri" + 0.010*"need"
# Topic: 72
# Words: 0.029*"error" + 0.022*"object" + 0.013*"follow" + 0.013*"need" + 0.013*"function" + 0.013*"tri" + 0.013*"code" + 0.012*"want" + 0.012*"jupyt" + 0.011*"instal"
# Topic: 73
# Words: 0.030*"imag" + 0.027*"work" + 0.018*"code" + 0.017*"button" + 0.016*"page" + 0.014*"show" + 0.013*"need" + 0.011*"screen" + 0.010*"exampl" + 0.010*"login"
# Topic: 74
# Words: 0.084*"python" + 0.042*"file" + 0.038*"line" + 0.022*"code" + 0.015*"user" + 0.015*"problem" + 0.014*"sheet" + 0.013*"packag" + 0.013*"tri" + 0.012*"tensorflow"
# Topic: 75
# Words: 0.040*"like" + 0.019*"tabl" + 0.016*"display" + 0.014*"data" + 0.014*"style" + 0.013*"databas" + 0.013*"custom" + 0.012*"visibl" + 0.012*"want" + 0.011*"user"
# Topic: 76
# Words: 0.017*"data" + 0.017*"error" + 0.017*"column" + 0.011*"like" + 0.011*"build" + 0.011*"work" + 0.010*"tri" + 0.010*"code" + 0.010*"click" + 0.009*"load"
# Topic: 77
# Words: 0.028*"like" + 0.021*"data" + 0.019*"code" + 0.018*"get" + 0.016*"tri" + 0.016*"file" + 0.015*"work" + 0.012*"type" + 0.011*"valu" + 0.011*"error"
# Topic: 78
# Words: 0.039*"error" + 0.027*"login" + 0.020*"know" + 0.015*"user" + 0.014*"flutter" + 0.014*"build" + 0.014*"firebas" + 0.012*"function" + 0.011*"tri" + 0.011*"task"
# Topic: 79
# Words: 0.046*"imag" + 0.025*"want" + 0.023*"like" + 0.023*"code" + 0.020*"tri" + 0.017*"list" + 0.016*"screen" + 0.013*"need" + 0.013*"work" + 0.013*"googl"
# Topic: 80
# Words: 0.037*"tool" + 0.035*"android" + 0.026*"gradl" + 0.025*"kotlin" + 0.023*"error" + 0.022*"build" + 0.017*"tri" + 0.017*"project" + 0.013*"work" + 0.013*"follow"
# Topic: 81
# Words: 0.013*"code" + 0.013*"vector" + 0.013*"follow" + 0.012*"error" + 0.011*"connect" + 0.011*"permiss" + 0.011*"distanc" + 0.010*"tri" + 0.010*"question" + 0.010*"work"
# Topic: 82
# Words: 0.042*"instal" + 0.021*"error" + 0.019*"updat" + 0.018*"like" + 0.015*"code" + 0.015*"follow" + 0.013*"project" + 0.012*"tri" + 0.012*"graph" + 0.011*"compos"
# Topic: 83
# Words: 0.087*"array" + 0.027*"object" + 0.022*"activ" + 0.015*"want" + 0.014*"format" + 0.013*"know" + 0.012*"crash" + 0.012*"code" + 0.011*"record" + 0.011*"call"
# Topic: 84
# Words: 0.030*"data" + 0.026*"build" + 0.016*"test" + 0.012*"error" + 0.012*"list" + 0.011*"pipelin" + 0.010*"tri" + 0.010*"page" + 0.010*"problem" + 0.010*"anim"
# Topic: 85
# Words: 0.020*"call" + 0.017*"function" + 0.016*"code" + 0.014*"work" + 0.014*"kotlin" + 0.013*"array" + 0.013*"servic" + 0.012*"error" + 0.012*"collect" + 0.011*"know"
# Topic: 86
# Words: 0.024*"tabl" + 0.017*"code" + 0.017*"need" + 0.015*"data" + 0.013*"node" + 0.013*"work" + 0.011*"error" + 0.010*"time" + 0.009*"build" + 0.009*"question"
# Topic: 87
# Words: 0.024*"state" + 0.022*"compon" + 0.020*"data" + 0.017*"page" + 0.015*"display" + 0.015*"user" + 0.014*"error" + 0.012*"month" + 0.012*"item" + 0.012*"code"
# Topic: 88
# Words: 0.028*"imag" + 0.023*"user" + 0.018*"azur" + 0.016*"creat" + 0.014*"string" + 0.013*"code" + 0.011*"server" + 0.010*"need" + 0.009*"delet" + 0.009*"https"
# Topic: 89
# Words: 0.020*"resourc" + 0.017*"error" + 0.016*"like" + 0.013*"work" + 0.012*"code" + 0.012*"file" + 0.010*"tri" + 0.010*"follow" + 0.009*"python" + 0.009*"android"
# Topic: 90
# Words: 0.023*"work" + 0.022*"tri" + 0.014*"imag" + 0.013*"want" + 0.012*"like" + 0.011*"function" + 0.010*"worker" + 0.009*"error" + 0.009*"class" + 0.009*"object"
# Topic: 91
# Words: 0.026*"packag" + 0.023*"project" + 0.021*"code" + 0.021*"want" + 0.019*"like" + 0.018*"tri" + 0.018*"react" + 0.014*"librari" + 0.013*"error" + 0.013*"creat"
# Topic: 92
# Words: 0.031*"modul" + 0.026*"intern" + 0.021*"error" + 0.016*"java" + 0.013*"user" + 0.013*"send" + 0.012*"tri" + 0.011*"connect" + 0.011*"script" + 0.009*"number"
# Topic: 93
# Words: 0.026*"azur" + 0.019*"pipelin" + 0.017*"server" + 0.016*"devop" + 0.014*"messag" + 0.013*"want" + 0.013*"valid" + 0.013*"tri" + 0.012*"error" + 0.011*"valu"
# Topic: 94
# Words: 0.027*"object" + 0.022*"code" + 0.017*"tri" + 0.016*"mongodb" + 0.013*"nginx" + 0.013*"servic" + 0.013*"work" + 0.012*"class" + 0.011*"core" + 0.011*"method"
# Topic: 95
# Words: 0.039*"column" + 0.031*"tabl" + 0.019*"function" + 0.017*"valu" + 0.015*"data" + 0.014*"tri" + 0.013*"queri" + 0.013*"need" + 0.012*"text" + 0.012*"return"
# Topic: 96
# Words: 0.021*"code" + 0.014*"user" + 0.013*"work" + 0.013*"want" + 0.012*"like" + 0.011*"tri" + 0.010*"generat" + 0.010*"need" + 0.009*"function" + 0.009*"server"
# Topic: 97
# Words: 0.033*"code" + 0.021*"work" + 0.020*"rout" + 0.017*"tri" + 0.017*"messag" + 0.015*"port" + 0.015*"send" + 0.015*"error" + 0.012*"follow" + 0.011*"data"
# Topic: 98
# Words: 0.040*"valu" + 0.017*"want" + 0.017*"like" + 0.015*"load" + 0.014*"file" + 0.012*"document" + 0.011*"json" + 0.011*"config" + 0.011*"tri" + 0.010*"look"
# Topic: 99
# Words: 0.023*"work" + 0.017*"code" + 0.013*"valu" + 0.013*"version" + 0.013*"list" + 0.012*"tri" + 0.010*"data" + 0.009*"error" + 0.009*"function" + 0.009*"problem"

# %%
for index, score in sorted(lda_model[bow_corpus[123]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.3369101285934448
# Topic: 0.021*"work" + 0.020*"tri" + 0.016*"code" + 0.014*"like" + 0.014*"function" + 0.012*"want" + 0.009*"script" + 0.009*"multipl" + 0.008*"help" + 0.008*"queri"
#
# Score: 0.22533059120178223
# Topic: 0.084*"python" + 0.042*"file" + 0.038*"line" + 0.022*"code" + 0.015*"user" + 0.015*"problem" + 0.014*"sheet" + 0.013*"packag" + 0.013*"tri" + 0.012*"tensorflow"
#
# Score: 0.22460071742534637
# Topic: 0.040*"valu" + 0.017*"want" + 0.017*"like" + 0.015*"load" + 0.014*"file" + 0.012*"document" + 0.011*"json" + 0.011*"config" + 0.011*"tri" + 0.010*"look"
#
# Score: 0.13080081343650818
# Topic: 0.033*"code" + 0.021*"work" + 0.020*"rout" + 0.017*"tri" + 0.017*"messag" + 0.015*"port" + 0.015*"send" + 0.015*"error" + 0.012*"follow" + 0.011*"data"
#
# Score: 0.06751255691051483
# Topic: 0.036*"notif" + 0.020*"work" + 0.019*"send" + 0.016*"push" + 0.015*"page" + 0.012*"type" + 0.011*"firebas" + 0.011*"build" + 0.011*"user" + 0.011*"time"

# %%
for index, score in sorted(lda_model_tfidf[bow_corpus[123]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.28146126866340637
# Topic: 0.074*"script" + 0.053*"execut" + 0.050*"want" + 0.043*"generat" + 0.041*"command" + 0.036*"advanc" + 0.034*"attempt" + 0.030*"databas" + 0.027*"thank" + 0.027*"follow"
#
# Score: 0.13415464758872986
# Topic: 0.079*"select" + 0.074*"base" + 0.069*"exampl" + 0.047*"multipl" + 0.045*"instanc" + 0.044*"singl" + 0.043*"switch" + 0.043*"simpl" + 0.042*"bootstrap" + 0.038*"dynam"
#
# Score: 0.10986842215061188
# Topic: 0.043*"give" + 0.037*"cell" + 0.033*"answer" + 0.026*"come" + 0.026*"swift" + 0.025*"caus" + 0.024*"memori" + 0.024*"help" + 0.022*"push" + 0.022*"ask"
#
# Score: 0.0893721729516983
# Topic: 0.044*"class" + 0.032*"differ" + 0.030*"number" + 0.029*"return" + 0.029*"object" + 0.029*"project" + 0.027*"method" + 0.027*"depend" + 0.021*"config" + 0.021*"line"
#
# Score: 0.07101408392190933
# Topic: 0.048*"string" + 0.045*"element" + 0.029*"loop" + 0.028*"field" + 0.024*"content" + 0.021*"delet" + 0.020*"exampl" + 0.018*"look" + 0.016*"creat" + 0.016*"kind"
#
# Score: 0.06367731839418411
# Topic: 0.283*"rout" + 0.209*"lambda" + 0.070*"subnet" + 0.045*"associ" + 0.018*"request" + 0.016*"localhost" + 0.007*"server" + 0.006*"endpoint" + 0.003*"articl" + 0.002*"account"
#
# Score: 0.0616089329123497
# Topic: 0.073*"instruct" + 0.071*"run" + 0.052*"processor" + 0.045*"code" + 0.044*"mention" + 0.041*"line" + 0.035*"recogn" + 0.034*"start" + 0.030*"boot" + 0.028*"track"
#
# Score: 0.039999328553676605
# Topic: 0.073*"compon" + 0.046*"error" + 0.046*"page" + 0.044*"display" + 0.042*"store" + 0.039*"fetch" + 0.035*"state" + 0.035*"throw" + 0.035*"trigger" + 0.033*"react"
#
# Score: 0.03894117847084999
# Topic: 0.131*"send" + 0.096*"messag" + 0.051*"local" + 0.043*"servic" + 0.032*"endpoint" + 0.031*"correct" + 0.031*"char" + 0.030*"encod" + 0.029*"topic" + 0.027*"context"
#
# Score: 0.03780962526798248
# Topic: 0.040*"json" + 0.026*"follow" + 0.024*"core" + 0.024*"remov" + 0.023*"issu" + 0.022*"work" + 0.021*"creat" + 0.019*"like" + 0.018*"file" + 0.017*"program"
#
# Score: 0.020916704088449478
# Topic: 0.142*"python" + 0.083*"environ" + 0.053*"virtual" + 0.041*"catalina" + 0.040*"maco" + 0.033*"ionic" + 0.025*"error" + 0.023*"instal" + 0.023*"entri" + 0.022*"conda"
#
# Score: 0.020500047132372856
# Topic: 0.122*"instal" + 0.060*"tool" + 0.059*"window" + 0.057*"control" + 0.056*"header" + 0.038*"mode" + 0.033*"guid" + 0.029*"option" + 0.024*"boot" + 0.021*"haven"
#
# Score: 0.01686081849038601
# Topic: 0.102*"java" + 0.064*"color" + 0.045*"test" + 0.037*"powershel" + 0.035*"thread" + 0.028*"jenkin" + 0.028*"build" + 0.022*"wait" + 0.022*"code" + 0.022*"channel"
