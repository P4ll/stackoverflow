# %%
import pandas as pd
import numpy as np
import gensim
import nltk
import logging
import pickle
import spacy
import math

import gensim.corpora as corpora

from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from gensim.models.coherencemodel import CoherenceModel
from gensim import corpora, models
from gensim.test.utils import datapath

from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
from scipy.stats import entropy
from tempfile import TemporaryFile

from scipy.special import (entr, rel_entr)
from numpy import (arange, putmask, ravel, ones, shape, ndarray, zeros, floor,
                   logical_and, log, sqrt, place, argmax, vectorize, asarray,
                   nan, inf, isinf, NINF, empty)

import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.ERROR)
import warnings
warnings.filterwarnings("ignore",category=DeprecationWarning)

np.random.seed(2020)

nltk.download('wordnet')
stemmer = SnowballStemmer('english')

DOC_COUNT = 100
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\P4L\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
my_stop_words = STOPWORDS.union(set(['use', 'be', 'work', 'user', 'try', 'cell',
                                     'row', 'want', 'item', 'go', 'get', 'add', 'went', 'tried',
                                    'return', 'sort', 'test', 'run', 'check', 'click', 'hour', 'minute', 'second',
                                    'version', 'app', 'paragraph', 'error', 'log', 'press',
                                    'need', 'feed', 'thank', 'way', 'like', 'kill', 'help']))

# %%
base_path = "D:/work/stackoverflow"
base_model = base_path + "models_data/"
base_dataset = base_path + "dataset/"
base_model_lda = base_model + "lda/"

# %%
def m_entropy(pk, qk=None, base=None, axis=0):
    pk = asarray(pk)
    pk = 1.0*pk / np.sum(pk, axis=axis, keepdims=True)
    if qk is None:
        vec = entr(pk)
    else:
        qk = asarray(qk)
        #if qk.shape != pk.shape:
            #raise ValueError("qk and pk must have same shape.")
        qk = 1.0*qk / np.sum(qk, axis=axis, keepdims=True)
        vec = rel_entr(pk, qk)
    S = np.sum(vec, axis=axis)
    if base is not None:
        S /= log(base)
    return S

def jensen_shannon(query, matrix):
    """
    This function implements a Jensen-Shannon similarity
    between the input query (an LDA topic distribution for a document)
    and the entire corpus of topic distributions.
    It returns an array of length M where M is the number of documents in the corpus
    """
    # lets keep with the p,q notation above
    p = query[None,:].T # take transpose
    q = matrix.T # transpose matrix

    #new = np.zeros((q.shape[0], q.shape[1]))
    #new[:q.shape[0], :1] = p
    #p = new
    
    m = 0.5*(p + q)
    return np.sqrt(0.5*(m_entropy(p,m) + m_entropy(q,m)))

def get_most_similar_documents(query,matrix,k=10):
    """
    This function implements the Jensen-Shannon distance above
    and retruns the top k indices of the smallest jensen shannon distances
    """
    sims = jensen_shannon(query,matrix) # list of jensen shannon distances
    out = [dist for dist in sims if not math.isnan(dist)]
    return sims.argsort()[:k], sorted(sims, reverse=True) # the top k positional index of the smallest Jensen Shannon distances

def clear_text(text):
    text = re.sub('<code>(.|\n)*?<\/code>', '', text)
    text = re.sub(r'(\<(/?[^>]+)>)', '', text)
    text = re.sub("[\'\"\\/\@\%\(\)\~\`\{\}]", '', text)
    text = re.sub('\s+', ' ', text)
    
    return text

def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v'))

def preprocess(text):
    text = clear_text(text)
    result = []
    #result = [token in gensim.utils.simple_preprocess(text, deacc=True) if ((token not in gensim.parsing.preprocessing.STOPWORDS) and len(token) > 1) == True]
    for token in gensim.utils.simple_preprocess(text, deacc=True):
        if (token not in my_stop_words) and len(token) > 1:
            #result.append(lemmatize_stemming(token))
            result.append(token)
    return result

# %%
def split_tags(text):
    if not isinstance(text, str) and math.isnan(text):
        return ''
    if text == '' or text == ' ':
        return text
    else:
        return text.replace('|', ' ')

def add_string(text, tags, n=3):
    tags = split_tags(tags)
    tags = ' ' + tags
    i = 0
    for i in range(n):
        if i % 2 == 0:
            text += tags
        else:
            text = tags + text
    return text

# %%
data = pd.read_csv(base_dataset + 'large_data.csv')
if DOC_COUNT != -1:
    data = data.head(DOC_COUNT)

titles = data['post_title'].values
tags = data['post_tags'].map(split_tags).values
data = [add_string(row['post_body'], row['post_tags'], 3) for _, row in data.iterrows()]
#data = data['post_body'].values

[data.append(z) for z in titles]
[data.append(z) for z in tags]
[data.append(z) for z in tags]
[data.append(z) for z in tags]
[data.append(z) for z in tags]

#data = np.array(data)
#data = np.append(data, titles)
#data = np.append(data, tags)
#data = np.append(data, tags)
#data = np.append(data, tags)
#data = np.append(data, tags)

print(len(data))
del titles
del tags
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-c760a0e12933> in <module>
# ----> 1 data = pd.read_csv(base_dataset + 'large_data.csv')
#       2 if DOC_COUNT != -1:
#       3     data = data.head(DOC_COUNT)
#       4
#       5 titles = data['post_title'].values
#
# d:\programs\python3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# d:\programs\python3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# d:\programs\python3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# d:\programs\python3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# d:\programs\python3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File D:/work/stackoverflowdataset/large_data.csv does not exist: 'D:/work/stackoverflowdataset/large_data.csv'

# %%
doc_sample = data[3]

print('original document: ')
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words)
print('\n\ntokenized and lemmatized document: ')
print(preprocess(doc_sample))
# Out:
# original document:
# ['', 'database', 'rdbms', 'ordbms<p>After', 'mounting', 'the', 'database', 'I', 'tried', 'executing', 'these', 'command-', 'alter', 'database', 'open;', 'emanating', 'from', 'a', 'shutdown', 'initialization', 'error', 'but', 'my', 'oracle', 'kept', 'returning', 'an', 'ORA-00600:', 'internal', 'error', 'code,', 'arguments', '[dbkif_find_next_record_1],', '[],', '[],', '[].\nPlease,', 'how', 'do', 'I', 'proceed', 'from', 'here?</p>', 'database', 'rdbms', 'ordbms', 'database', 'rdbms', 'ordbms']
#
#
# tokenized and lemmatized document:
# ['database', 'rdbms', 'ordbmsafter', 'mounting', 'database', 'executing', 'command', 'alter', 'database', 'open', 'emanating', 'shutdown', 'initialization', 'oracle', 'kept', 'returning', 'ora', 'internal', 'code', 'arguments', 'proceed', 'database', 'rdbms', 'ordbms', 'database', 'rdbms', 'ordbms']

# %%
processed_docs = np.array([preprocess(x) for x in data])
del data

# %%
bigram = gensim.models.Phrases(processed_docs, min_count=5, threshold=100)
trigram = gensim.models.Phrases(bigram[processed_docs], threshold=100)

bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

# %%
bigram_mod.save(datapath(base_model + "ngrams/bigram_mod"))
trigram_mod.save(datapath(base_model + "ngrams/trigram_mod"))

# %%
def make_bigrams(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigrams(texts):
    return [trigram_mod[bigram_mod[doc]] for doc in texts]

def lemmatization(texts, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV']):
    texts_out = []
    for sent in texts:
        doc = nlp(" ".join(sent)) 
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags and not token.lemma_ in my_stop_words])
    return texts_out

# %%
processed_docs = make_bigrams(processed_docs)
processed_docs = make_trigrams(processed_docs)

nlp = spacy.load('en_core_web_sm', disable=['parser', 'ner'])

processed_docs = lemmatization(processed_docs, allowed_postags=['NOUN', 'ADJ', 'VERB', 'ADV'])

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
lda_model = gensim.models.ldamodel.LdaModel(corpus=bow_corpus,
                                           id2word=dictionary,
                                           num_topics=300,
                                           random_state=100,
                                           update_every=2,
                                           chunksize=50000,
                                           passes=15)

print('\nPerplexity: ', lda_model.log_perplexity(bow_corpus))

coherence_model_lda = CoherenceModel(model=lda_model, texts=processed_docs, dictionary=dictionary, coherence='c_v')
coherence_lda = coherence_model_lda.get_coherence()
print('\nCoherence Score: ', coherence_lda)
# Out:
# Perplexity:  -18.07849637275526
#
# Coherence Score:  0.47145036332862

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.265*"range" + 0.194*"certain" + 0.147*"dictionary" + 0.098*"criterion" + 0.080*"spinner" + 0.021*"paper" + 0.020*"toad" + 0.012*"unnecessary" + 0.011*"patient" + 0.011*"bellow"
# Topic: 1 Word: 0.194*"drupal" + 0.061*"mule" + 0.036*"resttemplate" + 0.034*"objectid" + 0.033*"silverstripe" + 0.030*"microsoft_graph_sdks" + 0.023*"kendo" + 0.023*"livedata" + 0.021*"turtle" + 0.018*"egg"
# Topic: 2 Word: 0.203*"publish" + 0.146*"bluetooth" + 0.141*"synchronization" + 0.065*"synchronize" + 0.041*"mathjax" + 0.031*"fish" + 0.026*"publishing" + 0.025*"deny" + 0.022*"putty" + 0.017*"portfolio"
# Topic: 3 Word: 0.414*"mysql" + 0.389*"query" + 0.049*"description" + 0.016*"queryset" + 0.010*"valueerror" + 0.008*"thanks_advance" + 0.006*"lag" + 0.004*"follow" + 0.004*"primary_key" + 0.004*"malforme"
# Topic: 4 Word: 0.531*"mongodb" + 0.185*"mongoose" + 0.155*"collection" + 0.018*"mix" + 0.015*"boto" + 0.011*"username" + 0.008*"emit" + 0.006*"aws_lambda" + 0.004*"enforce" + 0.004*"profiler"
# Topic: 5 Word: 0.114*"deprecate" + 0.102*"alternative" + 0.090*"longer" + 0.064*"formik" + 0.058*"identifier" + 0.051*"newly" + 0.048*"introduce" + 0.043*"const" + 0.036*"ideal" + 0.025*"diff"
# Topic: 6 Word: 0.503*"stream" + 0.192*"streaming" + 0.023*"www" + 0.019*"modification" + 0.019*"organization" + 0.017*"unauthorized" + 0.016*"odata" + 0.013*"vault" + 0.011*"debounce" + 0.009*"participant"
# Topic: 7 Word: 0.227*"fact" + 0.052*"prolog" + 0.052*"minecraft" + 0.033*"subform" + 0.027*"reusability" + 0.025*"supervisord" + 0.020*"permanent" + 0.019*"ticker" + 0.013*"chainer" + 0.013*"roblox"
# Topic: 8 Word: 0.217*"translation" + 0.145*"translate" + 0.071*"wpf_xaml_mvvm" + 0.048*"simultaneously" + 0.036*"symlink" + 0.026*"attendance" + 0.019*"flight" + 0.017*"phpi" + 0.015*"translator" + 0.014*"azureportal"
# Topic: 9 Word: 0.492*"share" + 0.046*"tslint" + 0.039*"visibility" + 0.028*"cocoa" + 0.027*"sharing" + 0.025*"mount" + 0.023*"octobercms_octobercms_plugin" + 0.013*"menuitem" + 0.012*"terrain" + 0.011*"transactional"
# Topic: 10 Word: 0.465*"package" + 0.155*"instal" + 0.078*"break" + 0.066*"py" + 0.051*"self" + 0.036*"json" + 0.022*"follow" + 0.005*"available" + 0.005*"fine" + 0.004*"successfully"
# Topic: 11 Word: 0.359*"graph" + 0.093*"represent" + 0.085*"interpolation" + 0.073*"individual" + 0.037*"separately" + 0.022*"individually" + 0.019*"recreate" + 0.018*"tensorboard" + 0.016*"resnet" + 0.015*"apart"
# Topic: 12 Word: 0.791*"ruby_rail" + 0.038*"rail" + 0.038*"bundle" + 0.029*"ruby_rails" + 0.029*"devise" + 0.006*"rake" + 0.006*"autohotkey" + 0.005*"deserialize" + 0.004*"graphql_apollo" + 0.004*"sage"
# Topic: 13 Word: 0.450*"cmake" + 0.067*"hint" + 0.055*"city" + 0.030*"transformer" + 0.025*"util" + 0.018*"qt" + 0.017*"ninja" + 0.012*"iife" + 0.010*"glfw" + 0.010*"sqlclient"
# Topic: 14 Word: 0.475*"nginx" + 0.195*"proxy" + 0.079*"agent" + 0.039*"raw" + 0.038*"forward" + 0.033*"kivy" + 0.020*"pure" + 0.010*"webclient" + 0.006*"impersonation" + 0.005*"ingress"
# Topic: 15 Word: 0.192*"production" + 0.192*"development" + 0.140*"phone" + 0.043*"id" + 0.041*"light" + 0.035*"gallery" + 0.024*"degree" + 0.020*"sidekiq" + 0.017*"license" + 0.015*"mirror"
# Topic: 16 Word: 0.285*"read" + 0.099*"documentation" + 0.072*"https" + 0.050*"mention" + 0.050*"accord" + 0.045*"follow" + 0.036*"github" + 0.033*"refer" + 0.031*"doc" + 0.026*"guide"
# Topic: 17 Word: 0.229*"conditional" + 0.108*"today" + 0.047*"originally" + 0.041*"netlify" + 0.036*"memcache" + 0.036*"ion" + 0.031*"prove" + 0.026*"blade" + 0.025*"bokeh" + 0.022*"marshal"
# Topic: 18 Word: 0.423*"sqlite" + 0.268*"chart" + 0.057*"composer" + 0.033*"tabulator" + 0.020*"materialize" + 0.018*"footer" + 0.018*"iterable" + 0.016*"virtualize" + 0.014*"storyboard" + 0.006*"windowe"
# Topic: 19 Word: 0.971*"server" + 0.006*"datasource" + 0.002*"nginx_reverse_proxy" + 0.001*"rbac" + 0.001*"odoo_odoo" + 0.001*"ansible_ansible_fact" + 0.001*"superglobal" + 0.000*"enumerable" + 0.000*"savechange" + 0.000*"webbrowser"
# Topic: 20 Word: 0.209*"realm" + 0.092*"probability" + 0.088*"rectangle" + 0.057*"clip" + 0.034*"seaborn" + 0.031*"straight" + 0.029*"chance" + 0.026*"sqlplus" + 0.024*"browse" + 0.022*"regression_linear_regression"
# Topic: 21 Word: 0.102*"cryptography" + 0.061*"fork" + 0.061*"moodle" + 0.046*"lighthouse" + 0.038*"datadog" + 0.038*"assistance" + 0.037*"tfsbuild" + 0.029*"parallel_processing_multiprocesse" + 0.027*"referenced" + 0.024*"setuptool"
# Topic: 22 Word: 0.894*"angular" + 0.075*"typescript" + 0.011*"routing" + 0.003*"changedetection" + 0.001*"extentreport" + 0.001*"formgroup" + 0.001*"ipv" + 0.001*"auto_increment" + 0.000*"cudnn" + 0.000*"sever"
# Topic: 23 Word: 0.200*"dynamically" + 0.189*"selection" + 0.135*"populate" + 0.099*"int" + 0.065*"angularfire" + 0.042*"plotly_plotly" + 0.021*"editable" + 0.020*"base" + 0.016*"enumerate" + 0.012*"sendkey"
# Topic: 24 Word: 0.304*"design" + 0.216*"product" + 0.120*"category" + 0.065*"software" + 0.060*"laravel" + 0.047*"complex" + 0.041*"relational" + 0.019*"aiohttp" + 0.010*"vendor" + 0.009*"commerce"
# Topic: 25 Word: 0.381*"key" + 0.234*"axio" + 0.100*"layer" + 0.051*"dimension" + 0.040*"pair" + 0.023*"workflow" + 0.018*"concatenate" + 0.015*"manipulate" + 0.009*"attention" + 0.007*"snowflake"
# Topic: 26 Word: 0.307*"rxj" + 0.199*"duplicate" + 0.154*"observable" + 0.100*"double" + 0.039*"reactor" + 0.029*"subscribe" + 0.026*"apple" + 0.017*"descriptor" + 0.008*"ship" + 0.007*"scalar"
# Topic: 27 Word: 0.208*"url" + 0.166*"localhost" + 0.145*"ide" + 0.068*"cart" + 0.055*"sync" + 0.042*"wamp" + 0.029*"autowire" + 0.026*"tsx" + 0.014*"aspect" + 0.013*"bandwidth"
# Topic: 28 Word: 0.221*"reason" + 0.177*"comment" + 0.049*"unknown" + 0.033*"redux_redux_thunk" + 0.032*"obvious" + 0.030*"javascript" + 0.027*"computation" + 0.025*"simulate" + 0.023*"exceed" + 0.020*"discover"
# Topic: 29 Word: 0.136*"close" + 0.091*"enable" + 0.076*"launch" + 0.074*"callback" + 0.054*"finish" + 0.051*"continue" + 0.051*"async" + 0.040*"force" + 0.030*"immediately" + 0.030*"soon"
# Topic: 30 Word: 0.733*"value" + 0.070*"null" + 0.013*"numeric" + 0.013*"base" + 0.010*"different" + 0.009*"follow" + 0.008*"multiple" + 0.007*"know" + 0.007*"look" + 0.006*"specific"
# Topic: 31 Word: 0.170*"kera" + 0.101*"pytorch" + 0.100*"shape" + 0.091*"loss" + 0.071*"training" + 0.058*"train" + 0.054*"prediction" + 0.045*"tensor" + 0.040*"predict" + 0.035*"reshape"
# Topic: 32 Word: 0.793*"function" + 0.106*"define" + 0.024*"scope" + 0.013*"odoo" + 0.011*"theory" + 0.002*"func" + 0.002*"know" + 0.001*"follow" + 0.001*"sqlbulkcopy" + 0.001*"mechanize"
# Topic: 33 Word: 0.328*"result" + 0.051*"follow" + 0.046*"actual" + 0.040*"assign" + 0.037*"expect" + 0.033*"desire" + 0.032*"textbox" + 0.029*"correspond" + 0.026*"different" + 0.024*"matrix"
# Topic: 34 Word: 0.689*"text" + 0.082*"webform" + 0.042*"boolean" + 0.033*"amchart" + 0.031*"wrap" + 0.016*"beta" + 0.006*"attack" + 0.004*"indent" + 0.004*"wrapping" + 0.004*"implicitly"
# Topic: 35 Word: 0.338*"field" + 0.288*"custom" + 0.143*"require" + 0.046*"definition" + 0.035*"advance" + 0.024*"optional" + 0.019*"buffer" + 0.013*"review" + 0.005*"slicing" + 0.004*"possible"
# Topic: 36 Word: 0.434*"csv" + 0.189*"promise" + 0.070*"room" + 0.057*"coverage" + 0.050*"activerecord" + 0.028*"powerpoint" + 0.018*"seed" + 0.016*"fortran" + 0.014*"puppeteer" + 0.011*"qemu"
# Topic: 37 Word: 0.314*"jenkin" + 0.084*"xmlhttprequ" + 0.052*"viewer" + 0.050*"flash" + 0.047*"trim" + 0.044*"clock" + 0.036*"apps" + 0.031*"instrument" + 0.025*"sandbox" + 0.023*"esp"
# Topic: 38 Word: 0.538*"animation" + 0.057*"book" + 0.048*"minimum" + 0.043*"crud" + 0.038*"author" + 0.031*"netbean" + 0.018*"suitable" + 0.014*"toast" + 0.011*"literally" + 0.010*"sapui"
# Topic: 39 Word: 0.459*"page" + 0.180*"single" + 0.079*"html" + 0.071*"sign" + 0.062*"flask" + 0.014*"multiple" + 0.007*"different" + 0.006*"vaadin" + 0.005*"fine" + 0.005*"instead"
# Topic: 40 Word: 0.582*"request" + 0.181*"response" + 0.055*"body" + 0.048*"bad" + 0.012*"swing" + 0.006*"guzzle" + 0.006*"adal" + 0.005*"expect" + 0.005*"respond" + 0.004*"accept"
# Topic: 41 Word: 0.244*"device" + 0.193*"location" + 0.163*"place" + 0.044*"reset" + 0.026*"overlay" + 0.018*"bound" + 0.016*"svn" + 0.015*"bluetooth_lowenergy" + 0.014*"preserve" + 0.013*"zone"
# Topic: 42 Word: 0.559*"search" + 0.202*"attribute" + 0.080*"assembly" + 0.019*"scheme" + 0.018*"ssr" + 0.009*"strong" + 0.007*"comparable" + 0.004*"simplified" + 0.004*"tostre" + 0.004*"aspx"
# Topic: 43 Word: 0.320*"multithreade" + 0.171*"site" + 0.110*"thread" + 0.098*"website" + 0.081*"block" + 0.045*"wait" + 0.045*"lock" + 0.026*"partial" + 0.012*"persistent" + 0.007*"lib"
# Topic: 44 Word: 0.874*"service" + 0.055*"grid" + 0.027*"amazon" + 0.006*"automatic" + 0.004*"destructure" + 0.002*"elasticsearch_logstash_elastic" + 0.001*"remotewebdriver" + 0.001*"watermark" + 0.001*"micro" + 0.001*"dedicate"
# Topic: 45 Word: 0.362*"controller" + 0.161*"present" + 0.090*"animate" + 0.056*"uikit" + 0.039*"viewcontroller" + 0.027*"phpmailer" + 0.024*"uiview" + 0.013*"apexchart" + 0.013*"nicely" + 0.013*"datareader"
# Topic: 46 Word: 0.887*"form" + 0.061*"submit" + 0.012*"simple" + 0.005*"submission" + 0.002*"formset" + 0.001*"edit" + 0.001*"multiple" + 0.001*"adminer" + 0.001*"refreshe" + 0.000*"lunch"
# Topic: 47 Word: 0.403*"right" + 0.179*"compare" + 0.042*"cucumber" + 0.033*"tile" + 0.031*"watch" + 0.028*"left" + 0.019*"hdf" + 0.019*"cluster_computing" + 0.017*"parenthesis" + 0.017*"projection"
# Topic: 48 Word: 0.422*"template" + 0.393*"spring" + 0.063*"boot" + 0.021*"photo" + 0.016*"secret" + 0.010*"startup" + 0.008*"customize" + 0.007*"readonly" + 0.004*"amqp" + 0.003*"logback"
# Topic: 49 Word: 0.394*"framework" + 0.217*"rest" + 0.215*"entity" + 0.106*"django" + 0.013*"expand" + 0.006*"renderer" + 0.004*"camel" + 0.003*"robot" + 0.002*"neural_network_deep_learne" + 0.002*"dialogfragment"
# Topic: 50 Word: 0.399*"generate" + 0.302*"report" + 0.063*"bug" + 0.026*"interceptor" + 0.025*"payload" + 0.012*"stand" + 0.011*"outline" + 0.010*"displaying" + 0.010*"administration" + 0.010*"rich"
# Topic: 51 Word: 0.340*"task" + 0.198*"configuration" + 0.093*"complete" + 0.092*"configure" + 0.076*"execution" + 0.028*"logstash" + 0.014*"asyncstorage" + 0.010*"finance" + 0.009*"celery" + 0.008*"flatbuffer"
# Topic: 52 Word: 0.553*"net" + 0.428*"core" + 0.004*"dotnet" + 0.002*"appsetting" + 0.001*"fiber" + 0.001*"ef" + 0.000*"dim" + 0.000*"pythonim" + 0.000*"unity_di" + 0.000*"netframework"
# Topic: 53 Word: 0.329*"stored_procedure" + 0.168*"serialization" + 0.091*"lead" + 0.046*"nullable" + 0.044*"modeling" + 0.042*"substring" + 0.027*"serialize" + 0.019*"webjob" + 0.019*"ghostscript" + 0.014*"reportbuilder"
# Topic: 54 Word: 0.154*"bot" + 0.144*"botframework" + 0.143*"gateway" + 0.121*"schema" + 0.074*"direct" + 0.058*"disk" + 0.028*"swap" + 0.019*"ipad" + 0.018*"xcode" + 0.017*"clickonce"
# Topic: 55 Word: 0.225*"feature" + 0.217*"pivot" + 0.201*"migration" + 0.087*"scenario" + 0.041*"migrate" + 0.016*"angle" + 0.014*"conditionally" + 0.014*"slicer" + 0.012*"uuid" + 0.008*"reproducible"
# Topic: 56 Word: 0.481*"android" + 0.151*"support" + 0.140*"expo" + 0.034*"keyword" + 0.033*"preview" + 0.024*"hardware" + 0.016*"span" + 0.015*"statsmodel" + 0.009*"chromium" + 0.005*"land"
# Topic: 57 Word: 0.516*"environment" + 0.161*"section" + 0.035*"equation" + 0.034*"textinput" + 0.028*"env" + 0.015*"zend" + 0.013*"carry" + 0.010*"substitute" + 0.010*"fcm" + 0.008*"different"
# Topic: 58 Word: 0.365*"open" + 0.282*"source" + 0.053*"codenameone" + 0.052*"monitor" + 0.045*"slide" + 0.013*"perforce" + 0.012*"flex" + 0.011*"discovery" + 0.010*"division" + 0.009*"detox"
# Topic: 59 Word: 0.432*"property" + 0.288*"bind" + 0.064*"attach" + 0.029*"rank" + 0.022*"gem" + 0.022*"specification" + 0.021*"ruby" + 0.008*"databinde" + 0.007*"base" + 0.006*"bullet"
# Topic: 60 Word: 0.504*"select" + 0.202*"option" + 0.054*"choose" + 0.049*"dropdown" + 0.026*"pick" + 0.020*"choice" + 0.020*"multiple" + 0.013*"friend" + 0.007*"able" + 0.006*"base"
# Topic: 61 Word: 0.193*"plotly" + 0.102*"comprehension" + 0.097*"testng" + 0.093*"equal" + 0.085*"intent" + 0.067*"moment" + 0.064*"schedule" + 0.058*"hive" + 0.031*"timezone" + 0.024*"offer"
# Topic: 62 Word: 0.415*"store" + 0.194*"connect" + 0.086*"networking" + 0.049*"jasmine" + 0.040*"simulator" + 0.013*"respond" + 0.013*"accessible" + 0.012*"pyomo" + 0.010*"disconnect" + 0.010*"onchange"
# Topic: 63 Word: 0.659*"view" + 0.076*"bar" + 0.056*"width" + 0.036*"accessibility" + 0.020*"base" + 0.011*"movie" + 0.009*"pickle" + 0.008*"gap" + 0.008*"tokenize" + 0.006*"blur"
# Topic: 64 Word: 0.235*"allow" + 0.153*"handling" + 0.132*"rule" + 0.103*"password" + 0.065*"prevent" + 0.059*"literal" + 0.051*"highlight" + 0.029*"restrict" + 0.011*"playground" + 0.011*"alternate"
# Topic: 65 Word: 0.251*"annotation" + 0.178*"webpack" + 0.149*"register" + 0.095*"subquery" + 0.034*"ienumerable" + 0.024*"webpacker" + 0.023*"octave" + 0.015*"webkit" + 0.011*"inspection" + 0.009*"rbenv"
# Topic: 66 Word: 0.424*"uitableview" + 0.091*"relation" + 0.061*"tableview" + 0.057*"tap" + 0.043*"reuse" + 0.025*"implicit" + 0.023*"activation" + 0.017*"movement" + 0.013*"critical" + 0.012*"puzzle"
# Topic: 67 Word: 0.470*"build" + 0.226*"fail" + 0.163*"gradle" + 0.025*"building" + 0.012*"succeed" + 0.007*"follow" + 0.007*"successfully" + 0.006*"fault" + 0.006*"wxwidget" + 0.005*"virtualenv"
# Topic: 68 Word: 0.345*"tree" + 0.221*"binary" + 0.093*"contact" + 0.089*"profile" + 0.040*"tooltip" + 0.039*"scripting" + 0.024*"thymeleaf" + 0.020*"insertion" + 0.012*"wide" + 0.008*"incremente"
# Topic: 69 Word: 0.489*"order" + 0.115*"high" + 0.085*"customer" + 0.049*"low" + 0.029*"maintain" + 0.018*"care" + 0.015*"twitt" + 0.013*"violation" + 0.009*"emotion" + 0.009*"star"
# Topic: 70 Word: 0.266*"repository" + 0.114*"sub" + 0.083*"short" + 0.071*"geolocation" + 0.040*"activate" + 0.033*"replacement" + 0.030*"administrator" + 0.026*"concat" + 0.026*"membership" + 0.018*"accurate"
# Topic: 71 Word: 0.385*"formula" + 0.236*"excel" + 0.144*"sum" + 0.044*"tracking" + 0.031*"powerquery" + 0.018*"chatbot" + 0.010*"worksheet" + 0.009*"telegram" + 0.008*"tie" + 0.006*"twitch"
# Topic: 72 Word: 0.171*"entry" + 0.107*"byte" + 0.101*"junit" + 0.089*"tkinter" + 0.082*"alignment" + 0.043*"padding" + 0.040*"shortcode" + 0.039*"align" + 0.036*"canvas" + 0.029*"colour"
# Topic: 73 Word: 0.529*"string" + 0.264*"stre" + 0.103*"convert" + 0.037*"hash" + 0.003*"functional_programme" + 0.003*"base" + 0.002*"mathematical" + 0.002*"tar" + 0.002*"sharepoint_sharepoint" + 0.002*"cascade"
# Topic: 74 Word: 0.439*"word" + 0.206*"stop" + 0.052*"appium" + 0.049*"robotframework" + 0.031*"special" + 0.030*"winforms_datagridview" + 0.015*"exercise" + 0.014*"regular_expression" + 0.011*"lack" + 0.009*"alternatively"
# Topic: 75 Word: 0.480*"change" + 0.179*"color" + 0.140*"background" + 0.024*"procedure" + 0.021*"gridview" + 0.020*"quote" + 0.009*"white" + 0.008*"lake" + 0.007*"modify" + 0.007*"different"
# Topic: 76 Word: 0.699*"class" + 0.059*"tab" + 0.053*"responsive" + 0.033*"signature" + 0.014*"base" + 0.007*"different" + 0.006*"scheduler" + 0.006*"rebuild" + 0.005*"heroku" + 0.005*"instantiate"
# Topic: 77 Word: 0.178*"cause" + 0.160*"platform" + 0.149*"crash" + 0.121*"happen" + 0.043*"strange" + 0.039*"encounter" + 0.037*"recognize" + 0.034*"teamcity" + 0.019*"usb" + 0.017*"suspect"
# Topic: 78 Word: 0.493*"send" + 0.106*"answer" + 0.047*"flink_flink_streame" + 0.044*"verify" + 0.033*"salesforce" + 0.019*"stdout" + 0.014*"shopify" + 0.013*"know" + 0.013*"sendgrid" + 0.010*"shall"
# Topic: 79 Word: 0.219*"draw" + 0.113*"manifest" + 0.096*"chain" + 0.070*"datagridview" + 0.054*"completion" + 0.026*"readable" + 0.024*"sit" + 0.024*"provision" + 0.020*"double_quote" + 0.020*"potential"
# Topic: 80 Word: 0.412*"layout" + 0.168*"keyboard" + 0.103*"asset" + 0.039*"reader" + 0.023*"plane" + 0.023*"jestj" + 0.019*"cube" + 0.009*"appdelegate" + 0.008*"feasible" + 0.008*"entitlement"
# Topic: 81 Word: 0.502*"create" + 0.199*"new" + 0.046*"operator" + 0.035*"operation" + 0.035*"perform" + 0.013*"complexity" + 0.010*"addition" + 0.010*"adapter" + 0.009*"algorithm" + 0.008*"know"
# Topic: 82 Word: 0.296*"join" + 0.174*"leave" + 0.161*"static" + 0.068*"webhook" + 0.033*"refactore" + 0.028*"country" + 0.023*"pytest" + 0.022*"collect" + 0.017*"pay" + 0.016*"pyt"
# Topic: 83 Word: 0.209*"wrong" + 0.191*"correct" + 0.119*"syntax" + 0.095*"attempt" + 0.056*"invalid" + 0.042*"follow" + 0.041*"proper" + 0.026*"evaluate" + 0.026*"equivalent" + 0.021*"coldfusion"
# Topic: 84 Word: 0.346*"tool" + 0.143*"ssl" + 0.106*"uwp" + 0.072*"head" + 0.042*"signing" + 0.030*"hololen" + 0.024*"cloudflare" + 0.019*"thrift" + 0.013*"devexpress" + 0.012*"switching"
# Topic: 85 Word: 0.812*"access" + 0.089*"port" + 0.013*"able" + 0.006*"ms" + 0.004*"directly" + 0.004*"neo_neo_apoc" + 0.003*"accessible" + 0.003*"folium" + 0.002*"datastage" + 0.002*"hiding"
# Topic: 86 Word: 0.103*"implement" + 0.085*"good" + 0.073*"provide" + 0.063*"achieve" + 0.049*"approach" + 0.040*"implementation" + 0.023*"delegate" + 0.020*"consider" + 0.020*"know" + 0.020*"follow"
# Topic: 87 Word: 0.167*"jquery" + 0.149*"menu" + 0.101*"manipulation" + 0.085*"designer" + 0.066*"intellisense" + 0.062*"registration" + 0.043*"ef_migration" + 0.033*"partitioning" + 0.032*"onesignal" + 0.025*"likely"
# Topic: 88 Word: 0.200*"picture" + 0.107*"stay" + 0.065*"cycle" + 0.060*"ecmascript" + 0.048*"grab" + 0.033*"sidebar" + 0.032*"jsfiddle" + 0.029*"slick" + 0.028*"mixin" + 0.018*"pic"
# Topic: 89 Word: 0.467*"pagination" + 0.083*"protocol_buffer" + 0.043*"grand_central_dispatch" + 0.039*"toolkit" + 0.021*"playing" + 0.016*"restaurant" + 0.016*"qlikview" + 0.014*"central" + 0.014*"responsive_design_media_querie" + 0.010*"pca"
# Topic: 90 Word: 0.405*"start" + 0.258*"end" + 0.088*"backend" + 0.046*"begin" + 0.030*"apollo" + 0.013*"millisecond" + 0.009*"mutation" + 0.009*"mocha" + 0.006*"shadow_dom" + 0.006*"filesize"
# Topic: 91 Word: 0.570*"set" + 0.082*"pattern" + 0.070*"true" + 0.046*"false" + 0.034*"amp" + 0.015*"strategy" + 0.010*"follow" + 0.007*"inventory" + 0.007*"correctly" + 0.006*"able"
# Topic: 92 Word: 0.178*"typescript" + 0.171*"mean" + 0.097*"stack" + 0.088*"express" + 0.073*"limit" + 0.044*"hit" + 0.032*"typescript_typing" + 0.029*"redi" + 0.027*"echo" + 0.026*"ip"
# Topic: 93 Word: 0.244*"step" + 0.169*"aws" + 0.155*"cli" + 0.139*"aw" + 0.047*"terraform" + 0.029*"middleware" + 0.021*"continuous_integration" + 0.017*"navigator" + 0.011*"microsoft_cognitive" + 0.010*"suite"
# Topic: 94 Word: 0.138*"monitoring" + 0.126*"ldap" + 0.078*"opencl" + 0.049*"facebook" + 0.039*"passing" + 0.035*"survey" + 0.034*"vlookup" + 0.029*"trial" + 0.028*"quaternion" + 0.021*"tcpclient"
# Topic: 95 Word: 0.255*"queue" + 0.203*"rabbitmq" + 0.155*"root" + 0.060*"consume" + 0.057*"consumer" + 0.023*"act" + 0.021*"okhttp" + 0.020*"tenant" + 0.015*"tail" + 0.010*"wicket"
# Topic: 96 Word: 0.293*"extend" + 0.098*"abstract" + 0.071*"codeblock" + 0.036*"plpgsql" + 0.029*"notation" + 0.021*"clipboard" + 0.020*"scapy" + 0.018*"monad" + 0.016*"servicestack" + 0.016*"loose"
# Topic: 97 Word: 0.577*"flutter" + 0.159*"woocommerce" + 0.048*"widget" + 0.042*"connector" + 0.040*"screenshot" + 0.030*"setstate" + 0.011*"blockchain" + 0.008*"expert" + 0.007*"sorting" + 0.004*"custom_fields_acfpro"
# Topic: 98 Word: 0.264*"java" + 0.192*"htaccess" + 0.145*"final" + 0.077*"rewrite" + 0.041*"cover" + 0.022*"unittest" + 0.019*"kindly" + 0.018*"tesseract" + 0.016*"strip" + 0.013*"sparkr"
# Topic: 99 Word: 0.302*"install" + 0.203*"installation" + 0.125*"title" + 0.077*"rotation" + 0.029*"quick" + 0.029*"rotate" + 0.026*"gitlab" + 0.020*"checkboxe" + 0.014*"botframework_microsoft_team" + 0.014*"pip"
# Topic: 100 Word: 0.203*"automatically" + 0.168*"manually" + 0.122*"refresh" + 0.077*"payment" + 0.045*"huge" + 0.038*"expire" + 0.034*"scan" + 0.026*"drool" + 0.024*"utilize" + 0.019*"tdd"
# Topic: 101 Word: 0.145*"cmd" + 0.103*"stage" + 0.074*"stuck" + 0.073*"intend" + 0.056*"middle" + 0.049*"restful" + 0.039*"knowledge" + 0.035*"circular" + 0.028*"limited" + 0.028*"guidance"
# Topic: 102 Word: 0.318*"write" + 0.181*"program" + 0.172*"save" + 0.043*"developer" + 0.029*"txt" + 0.019*"know" + 0.019*"temporary" + 0.016*"writing" + 0.011*"simple" + 0.011*"problem"
# Topic: 103 Word: 0.621*"web" + 0.146*"api" + 0.115*"security" + 0.062*"scraping" + 0.015*"progressive" + 0.010*"servlet" + 0.008*"pymongo" + 0.001*"violate" + 0.001*"distortion" + 0.001*"floating_point_rounde"
# Topic: 104 Word: 0.369*"codeigniter" + 0.190*"asynchronous" + 0.151*"databrick" + 0.035*"cloudformation" + 0.029*"clion" + 0.021*"synchronous" + 0.016*"notebook" + 0.014*"guard" + 0.014*"rds" + 0.011*"asynchronously"
# Topic: 105 Word: 0.330*"integration" + 0.187*"conversion" + 0.129*"theme" + 0.078*"wordpress_wordpress_theme" + 0.042*"httprequ" + 0.033*"overflow" + 0.017*"anonymous" + 0.017*"advantage" + 0.015*"alpha" + 0.009*"primitive"
# Topic: 106 Word: 0.239*"checkbox" + 0.184*"textview" + 0.044*"clickable" + 0.040*"goroutine" + 0.033*"slave" + 0.027*"varchar" + 0.019*"remoting" + 0.017*"hybrid_connection" + 0.016*"stumble" + 0.016*"template_specialization"
# Topic: 107 Word: 0.368*"screen" + 0.152*"encryption" + 0.067*"fit" + 0.047*"generation" + 0.046*"param" + 0.040*"duration" + 0.030*"cancel" + 0.028*"encrypt" + 0.021*"smooth" + 0.018*"clojure"
# Topic: 108 Word: 0.391*"control" + 0.126*"flow" + 0.084*"hover" + 0.063*"filesystem" + 0.059*"plan" + 0.051*"resolution" + 0.050*"cloudwatch" + 0.024*"arrow" + 0.013*"duplication" + 0.011*"conversation"
# Topic: 109 Word: 0.625*"sheet" + 0.054*"team" + 0.047*"hyperlink" + 0.036*"win" + 0.034*"formatting" + 0.024*"cost" + 0.017*"jump" + 0.016*"transpose" + 0.015*"binaryfile" + 0.012*"diagnostic"
# Topic: 110 Word: 0.211*"dependency" + 0.186*"unable" + 0.115*"maven" + 0.108*"resolve" + 0.081*"depend" + 0.059*"dependencie" + 0.032*"artifact" + 0.023*"metal" + 0.017*"runner" + 0.014*"gstreamer"
# Topic: 111 Word: 0.369*"oracle" + 0.266*"sdk" + 0.195*"pipeline" + 0.041*"sharepoint" + 0.016*"logging" + 0.015*"pipelines_release_pipeline" + 0.012*"syncfusion" + 0.006*"active_directory" + 0.005*"gsub" + 0.003*"lua"
# Topic: 112 Word: 0.272*"export" + 0.222*"transaction" + 0.163*"timestamp" + 0.064*"interval" + 0.063*"listener" + 0.020*"avfoundation" + 0.020*"meet" + 0.017*"personal" + 0.014*"subtract" + 0.009*"logo"
# Topic: 113 Word: 0.297*"calculate" + 0.151*"average" + 0.065*"yield" + 0.052*"adjust" + 0.043*"uiimage" + 0.030*"temperature" + 0.020*"playback" + 0.019*"radio_button" + 0.016*"appearance" + 0.014*"datasets_tensorflow_estimator"
# Topic: 114 Word: 0.543*"model" + 0.357*"material" + 0.011*"curve" + 0.009*"bubble" + 0.009*"spread" + 0.005*"cloudkit" + 0.004*"estimate" + 0.004*"fitting" + 0.004*"htaccess_redirect" + 0.004*"linear"
# Topic: 115 Word: 0.293*"transfer" + 0.075*"ffmpeg" + 0.068*"meteor" + 0.065*"compatibility" + 0.035*"logcat" + 0.033*"recover" + 0.023*"landscape" + 0.020*"electron_electron_build" + 0.013*"portrait" + 0.013*"fasta"
# Topic: 116 Word: 0.628*"docker" + 0.159*"container" + 0.115*"host" + 0.024*"dockerfile" + 0.012*"openshift" + 0.006*"registry" + 0.005*"gesture" + 0.005*"legacy" + 0.004*"serilog" + 0.003*"bigtable"
# Topic: 117 Word: 0.184*"graphql" + 0.144*"traffic" + 0.064*"boxplot" + 0.045*"mapbox_gl" + 0.042*"workbook" + 0.040*"vmware_clarity" + 0.028*"contentful" + 0.015*"gaps_island" + 0.015*"decorate" + 0.009*"decouple"
# Topic: 118 Word: 0.179*"comparison" + 0.174*"wpf_mvvm" + 0.110*"viewmodel" + 0.043*"dagger" + 0.023*"resample" + 0.022*"collider" + 0.022*"quit" + 0.019*"overhead" + 0.018*"sectionlist" + 0.017*"webview"
# Topic: 119 Word: 0.359*"message" + 0.139*"receive" + 0.104*"account" + 0.035*"topic" + 0.032*"follow" + 0.024*"company" + 0.014*"tcp" + 0.010*"broker" + 0.010*"able" + 0.009*"incoming"
# Topic: 120 Word: 0.380*"elasticsearch" + 0.349*"index" + 0.059*"clause" + 0.050*"calculation" + 0.023*"quantity" + 0.011*"forecast" + 0.009*"shop" + 0.008*"privacy" + 0.007*"alia" + 0.003*"lubridate"
# Topic: 121 Word: 0.090*"iterator" + 0.086*"union" + 0.073*"square" + 0.066*"spatial" + 0.056*"dask" + 0.041*"composition" + 0.034*"msal" + 0.034*"compose" + 0.031*"wagtail" + 0.031*"limitation"
# Topic: 122 Word: 0.264*"redux" + 0.215*"react" + 0.203*"router" + 0.114*"state" + 0.087*"redirect" + 0.036*"reactjs" + 0.012*"persist" + 0.012*"luman" + 0.011*"dispatch" + 0.008*"reducer"
# Topic: 123 Word: 0.510*"list" + 0.201*"link" + 0.117*"dynamic" + 0.115*"winform" + 0.009*"mlkit" + 0.003*"slash" + 0.002*"bing" + 0.002*"geoserver" + 0.002*"virtual_reality" + 0.002*"brace"
# Topic: 124 Word: 0.476*"video" + 0.096*"reduce" + 0.088*"timer" + 0.049*"shift" + 0.020*"editing" + 0.020*"balance" + 0.016*"ambiguous" + 0.013*"revision" + 0.011*"countdowntimer" + 0.010*"tim"
# Topic: 125 Word: 0.434*"objective" + 0.118*"capture" + 0.084*"purchase" + 0.061*"pool" + 0.038*"packet" + 0.033*"destructor" + 0.021*"fatal" + 0.015*"voice" + 0.014*"analyze" + 0.010*"handshake"
# Topic: 126 Word: 0.523*"replace" + 0.060*"sequelize" + 0.030*"firewall" + 0.027*"everytime" + 0.026*"typing" + 0.024*"rails_activerecord" + 0.020*"rails_activestorage" + 0.014*"raspberry_pi" + 0.014*"rtsp" + 0.011*"bite"
# Topic: 127 Word: 0.201*"stick" + 0.080*"webgl" + 0.056*"telnet" + 0.054*"amcharts_amchart" + 0.050*"similarity" + 0.049*"sticky" + 0.032*"intervention" + 0.021*"eureka" + 0.021*"qml" + 0.020*"iptable"
# Topic: 128 Word: 0.267*"permission" + 0.174*"tag" + 0.131*"analytic" + 0.077*"insight" + 0.058*"track" + 0.053*"alert" + 0.025*"webserver" + 0.014*"grant" + 0.014*"testflight" + 0.013*"meta"
# Topic: 129 Word: 0.290*"rust" + 0.211*"standard" + 0.146*"non" + 0.034*"occurrence" + 0.029*"delimiter" + 0.029*"evaluation" + 0.018*"datatype" + 0.015*"sympy" + 0.014*"covariance" + 0.013*"enumeration"
# Topic: 130 Word: 0.751*"code" + 0.058*"status" + 0.044*"follow" + 0.025*"office" + 0.008*"checkout" + 0.008*"fine" + 0.007*"assertion" + 0.006*"working" + 0.005*"know" + 0.004*"overriding"
# Topic: 131 Word: 0.352*"symfony" + 0.271*"cloud" + 0.232*"config" + 0.030*"registry" + 0.011*"yml" + 0.006*"preact" + 0.005*"sqldw" + 0.005*"boilerplate" + 0.004*"imageview" + 0.004*"theming"
# Topic: 132 Word: 0.421*"debug" + 0.206*"target" + 0.053*"breakpoint" + 0.051*"cs" + 0.034*"spawn" + 0.018*"magic" + 0.016*"bundler" + 0.009*"superclass" + 0.008*"puma" + 0.007*"mono"
# Topic: 133 Word: 0.258*"handle" + 0.231*"engine" + 0.231*"exception" + 0.087*"throw" + 0.060*"occur" + 0.032*"catch" + 0.017*"blazor" + 0.011*"flatten" + 0.004*"calculated" + 0.004*"io"
# Topic: 134 Word: 0.162*"escape" + 0.126*"jestjs" + 0.116*"slider" + 0.074*"transformation" + 0.049*"radio" + 0.029*"interpret" + 0.028*"publisher" + 0.027*"decodable" + 0.023*"caption" + 0.021*"uiimageview"
# Topic: 135 Word: 0.236*"worker" + 0.221*"cache" + 0.116*"clear" + 0.088*"blank" + 0.064*"caching" + 0.058*"postgre" + 0.018*"yarnpkg" + 0.015*"apollo_apollo_client" + 0.015*"sequential" + 0.014*"loadable"
# Topic: 136 Word: 0.329*"tensorflow" + 0.153*"cento" + 0.152*"append" + 0.064*"gpu" + 0.052*"svg" + 0.044*"pc" + 0.018*"behave" + 0.017*"ping" + 0.016*"rstudio" + 0.010*"durable_function"
# Topic: 137 Word: 0.188*"opengl" + 0.177*"coordinate" + 0.134*"tuple" + 0.111*"normal" + 0.065*"texture" + 0.039*"shader" + 0.033*"dynamic_memory_allocation" + 0.030*"std" + 0.029*"vertex" + 0.018*"scanf"
# Topic: 138 Word: 0.204*"listview" + 0.106*"compute" + 0.095*"trace" + 0.081*"homebrew" + 0.072*"secure" + 0.031*"particle" + 0.026*"initiate" + 0.024*"parallax" + 0.020*"latency" + 0.017*"trap"
# Topic: 139 Word: 0.230*"selenium" + 0.153*"member" + 0.146*"private" + 0.128*"graphic" + 0.060*"binding" + 0.037*"webdriver" + 0.024*"geckodriver" + 0.022*"firefox" + 0.018*"rsa" + 0.014*"snap"
# Topic: 140 Word: 0.246*"remove" + 0.234*"exist" + 0.157*"delete" + 0.080*"old" + 0.028*"association" + 0.028*"polymer" + 0.023*"anymore" + 0.019*"belong" + 0.009*"comma" + 0.008*"community"
# Topic: 141 Word: 0.492*"update" + 0.182*"record" + 0.053*"late" + 0.038*"iterate" + 0.022*"weblogic" + 0.017*"userform" + 0.011*"dict" + 0.010*"handlebar" + 0.009*"mapbox" + 0.007*"thousand"
# Topic: 142 Word: 0.391*"wordpress" + 0.156*"ansible" + 0.141*"import" + 0.128*"module" + 0.061*"role" + 0.016*"subprocess" + 0.013*"ansible_ansible" + 0.012*"strut" + 0.006*"delphi" + 0.006*"package_manager"
# Topic: 143 Word: 0.171*"pyspark" + 0.104*"parquet" + 0.069*"truncate" + 0.063*"invoice" + 0.054*"hub" + 0.043*"shapely" + 0.032*"schematic" + 0.019*"curse" + 0.017*"credit" + 0.016*"promisekit"
# Topic: 144 Word: 0.171*"play" + 0.141*"xml" + 0.098*"soap" + 0.081*"auto" + 0.065*"grail" + 0.058*"httpclient" + 0.055*"integrate" + 0.037*"sound" + 0.030*"scipy" + 0.027*"artificial_intelligence"
# Topic: 145 Word: 0.168*"chunk" + 0.081*"permalink" + 0.077*"elementor" + 0.062*"corrupt" + 0.030*"media" + 0.028*"speech_recognition" + 0.028*"infile" + 0.027*"openxml" + 0.024*"virtualhost" + 0.016*"handsontable"
# Topic: 146 Word: 0.251*"case" + 0.152*"understand" + 0.052*"explain" + 0.044*"learn" + 0.043*"numpy" + 0.042*"tutorial" + 0.042*"follow" + 0.018*"understanding" + 0.017*"know" + 0.017*"cut"
# Topic: 147 Word: 0.253*"dom" + 0.193*"big" + 0.098*"nested" + 0.090*"calendar" + 0.074*"clone" + 0.033*"pause" + 0.018*"instagram" + 0.018*"partially" + 0.015*"resume" + 0.008*"outdate"
# Topic: 148 Word: 0.176*"turn" + 0.094*"keras_deep_learne" + 0.084*"red" + 0.079*"recognition" + 0.077*"factor" + 0.048*"keras_deep_learning" + 0.042*"surface" + 0.035*"convolution" + 0.034*"blue" + 0.031*"green"
# Topic: 149 Word: 0.246*"size" + 0.148*"large" + 0.101*"small" + 0.062*"multi" + 0.059*"touch" + 0.056*"serve" + 0.052*"routing" + 0.048*"cocoapod" + 0.026*"permutation" + 0.019*"draggable"
# Topic: 150 Word: 0.441*"processing" + 0.294*"upload" + 0.064*"conv_neural_network" + 0.028*"uploading" + 0.025*"segmentation" + 0.017*"patch" + 0.016*"multer" + 0.016*"uploaded" + 0.008*"yarn" + 0.004*"cassandra"
# Topic: 151 Word: 0.196*"scroll" + 0.190*"transition" + 0.181*"cosmosdb" + 0.079*"reach" + 0.077*"timeout" + 0.049*"behaviour" + 0.014*"fade" + 0.013*"associative" + 0.009*"scrolltop" + 0.009*"min"
# Topic: 152 Word: 0.310*"dataset" + 0.211*"statistic" + 0.100*"distribution" + 0.091*"machine_learning" + 0.026*"twitter_bootstrap" + 0.023*"bigquery" + 0.015*"cloudfront" + 0.014*"deep_learne" + 0.014*"sybase" + 0.007*"dbeaver"
# Topic: 153 Word: 0.128*"hold" + 0.117*"mouse" + 0.105*"rename" + 0.097*"indicate" + 0.039*"roll" + 0.036*"indicator" + 0.033*"having_trouble" + 0.031*"interact" + 0.028*"adapt" + 0.026*"chip"
# Topic: 154 Word: 0.474*"line" + 0.227*"command" + 0.104*"bash" + 0.030*"prompt" + 0.028*"shell" + 0.020*"follow" + 0.015*"bitbucket" + 0.011*"vhdl" + 0.008*"observer" + 0.006*"instant"
# Topic: 155 Word: 0.164*"initialization" + 0.115*"initialize" + 0.095*"round" + 0.094*"decimal" + 0.069*"decorator" + 0.047*"reflect" + 0.036*"subdirectory" + 0.028*"complain" + 0.027*"interop" + 0.027*"predicate"
# Topic: 156 Word: 0.308*"tsql" + 0.298*"font" + 0.152*"desktop" + 0.015*"recommendation" + 0.014*"fpm" + 0.012*"calc" + 0.011*"wkwebview" + 0.010*"narrow" + 0.010*"remotely" + 0.007*"fee"
# Topic: 157 Word: 0.326*"reference" + 0.175*"undefined" + 0.107*"behavior" + 0.075*"notice" + 0.043*"focus" + 0.038*"weird" + 0.027*"conditional_statement" + 0.018*"undefine" + 0.015*"differently" + 0.015*"freemarker"
# Topic: 158 Word: 0.394*"regex" + 0.270*"match" + 0.078*"internal" + 0.072*"loader" + 0.070*"provider" + 0.011*"dispose" + 0.007*"ahead" + 0.007*"slf" + 0.005*"dataflow" + 0.004*"textfield"
# Topic: 159 Word: 0.646*"sql" + 0.066*"linq" + 0.034*"playframework" + 0.022*"databinding" + 0.018*"snakemake" + 0.017*"pdo" + 0.014*"innodb" + 0.011*"wildcard" + 0.010*"swiper" + 0.009*"logical_operator"
# Topic: 160 Word: 0.466*"react" + 0.446*"native" + 0.057*"navigation" + 0.006*"base" + 0.002*"availability" + 0.002*"intl" + 0.001*"synonyms" + 0.001*"onscroll" + 0.001*"synonym" + 0.001*"nativei"
# Topic: 161 Word: 0.463*"trigger" + 0.105*"directive" + 0.072*"razor" + 0.042*"selenium_chromedriver" + 0.040*"listen" + 0.031*"se" + 0.025*"immutability" + 0.015*"settimeout" + 0.015*"codeception" + 0.014*"gather"
# Topic: 162 Word: 0.283*"point" + 0.272*"map" + 0.062*"signal" + 0.052*"foreach" + 0.050*"parallel" + 0.050*"direction" + 0.025*"ctype" + 0.024*"beautifulsoup" + 0.021*"summary" + 0.018*"mixed"
# Topic: 163 Word: 0.403*"process" + 0.200*"child" + 0.095*"swiftui" + 0.084*"parent" + 0.029*"sass" + 0.016*"infrastructure" + 0.015*"phpunit" + 0.014*"splitting" + 0.012*"inspector" + 0.009*"snmp"
# Topic: 164 Word: 0.488*"interface" + 0.086*"experience" + 0.069*"multiprocessing" + 0.043*"multiprocesse" + 0.033*"snapshot" + 0.024*"broadcast" + 0.022*"collision" + 0.014*"gatle" + 0.012*"fusion" + 0.010*"sharding"
# Topic: 165 Word: 0.296*"network" + 0.257*"socket" + 0.168*"programming" + 0.034*"offline" + 0.020*"pack" + 0.017*"restriction" + 0.016*"communicate" + 0.015*"peer" + 0.012*"quality" + 0.011*"fbsdk"
# Topic: 166 Word: 0.474*"column" + 0.074*"condition" + 0.065*"multiple" + 0.060*"base" + 0.043*"combine" + 0.021*"dataframe" + 0.019*"distinct" + 0.017*"different" + 0.017*"look" + 0.014*"dplyr"
# Topic: 167 Word: 0.150*"inheritance" + 0.150*"cluster" + 0.114*"lambda" + 0.099*"constant" + 0.072*"instruction" + 0.071*"overload" + 0.059*"derive" + 0.033*"multiple" + 0.017*"lint" + 0.015*"variadic"
# Topic: 168 Word: 0.398*"logic" + 0.181*"emulator" + 0.058*"subject" + 0.032*"immutable" + 0.026*"school" + 0.021*"inner_join" + 0.019*"plsql" + 0.015*"fraction" + 0.013*"teacher" + 0.010*"rfid"
# Topic: 169 Word: 0.281*"information" + 0.113*"center" + 0.111*"info" + 0.079*"additional" + 0.069*"flag" + 0.064*"swagger" + 0.022*"systemd" + 0.021*"continuous" + 0.016*"forget" + 0.014*"logical"
# Topic: 170 Word: 0.503*"testing" + 0.127*"unit_teste" + 0.088*"mock" + 0.053*"purpose" + 0.021*"elastic" + 0.021*"manual" + 0.018*"interactive" + 0.015*"shadow" + 0.012*"nunit" + 0.011*"hangfire"
# Topic: 171 Word: 0.908*"image" + 0.009*"pixel" + 0.005*"dockerhub" + 0.005*"base" + 0.004*"compress" + 0.004*"original" + 0.002*"imageview" + 0.002*"jpeg" + 0.002*"marshmallow" + 0.002*"multiple"
# Topic: 172 Word: 0.162*"skip" + 0.074*"utility" + 0.054*"writer" + 0.042*"cd" + 0.035*"webapps" + 0.035*"workbox" + 0.028*"actioncable" + 0.018*"truffle" + 0.018*"authenticator" + 0.014*"mvvm_light"
# Topic: 173 Word: 0.244*"label" + 0.132*"axis" + 0.076*"matplotlib" + 0.066*"matching" + 0.059*"simulation" + 0.046*"verification" + 0.045*"gtk" + 0.032*"respectively" + 0.028*"subplot" + 0.026*"tweet"
# Topic: 174 Word: 0.207*"mail" + 0.157*"gmail" + 0.034*"outcome" + 0.033*"major" + 0.033*"seperate" + 0.029*"dimensional" + 0.023*"lxml" + 0.022*"tax" + 0.022*"measurement" + 0.020*"st"
# Topic: 175 Word: 0.395*"component" + 0.232*"reactjs" + 0.162*"render" + 0.053*"prop" + 0.042*"rendering" + 0.017*"webstorm" + 0.011*"eslint" + 0.008*"prepare" + 0.006*"httprequest" + 0.004*"jsx"
# Topic: 176 Word: 0.189*"current" + 0.123*"context" + 0.115*"day" + 0.086*"previous" + 0.064*"month" + 0.060*"year" + 0.046*"history" + 0.038*"week" + 0.034*"perl" + 0.032*"deserialization"
# Topic: 177 Word: 0.640*"time" + 0.083*"long" + 0.060*"real" + 0.020*"delay" + 0.019*"multiple" + 0.019*"twice" + 0.015*"series" + 0.012*"sleep" + 0.008*"different" + 0.006*"lot"
# Topic: 178 Word: 0.542*"method" + 0.200*"instance" + 0.035*"invoke" + 0.022*"recursive" + 0.014*"multiple" + 0.014*"doctrine_orm" + 0.011*"subclass" + 0.010*"design_pattern" + 0.008*"different" + 0.008*"follow"
# Topic: 179 Word: 0.592*"loop" + 0.213*"nest" + 0.111*"struct" + 0.016*"itertool" + 0.013*"looping" + 0.006*"printf" + 0.001*"multiple" + 0.001*"gganimate" + 0.001*"theoretical" + 0.001*"treeset"
# Topic: 180 Word: 0.308*"driver" + 0.083*"restore" + 0.065*"affect" + 0.063*"black" + 0.059*"gradient" + 0.053*"cordova_cordova_plugin" + 0.051*"linux" + 0.028*"toolbox" + 0.020*"gnu" + 0.015*"collation"
# Topic: 181 Word: 0.480*"button" + 0.104*"editor" + 0.064*"disable" + 0.039*"js" + 0.037*"edit" + 0.029*"ckeditor" + 0.025*"anchor" + 0.019*"disabled" + 0.012*"yii" + 0.011*"suddenly"
# Topic: 182 Word: 0.329*"document" + 0.177*"reporting" + 0.086*"parsing" + 0.063*"math" + 0.051*"business" + 0.032*"ready" + 0.024*"listbox" + 0.015*"messagebox" + 0.012*"abstract_syntax" + 0.011*"grammar"
# Topic: 183 Word: 0.232*"language" + 0.220*"domain" + 0.129*"tomcat" + 0.121*"cross" + 0.047*"codable" + 0.015*"scrollview" + 0.013*"hst" + 0.012*"english" + 0.009*"plesk" + 0.007*"multiple"
# Topic: 184 Word: 0.291*"library" + 0.209*"include" + 0.133*"compiler" + 0.091*"compile" + 0.060*"compilation" + 0.036*"executable" + 0.032*"makefile" + 0.026*"gcc" + 0.009*"cpp" + 0.006*"preprocessor"
# Topic: 185 Word: 0.144*"card" + 0.109*"datetime" + 0.080*"student" + 0.079*"float" + 0.078*"lstm" + 0.077*"extj" + 0.063*"hand" + 0.055*"negative" + 0.028*"positive" + 0.023*"pie"
# Topic: 186 Word: 0.340*"input" + 0.332*"output" + 0.100*"expect" + 0.078*"enter" + 0.019*"validator" + 0.012*"follow" + 0.008*"instead" + 0.007*"inputs" + 0.005*"toolbar" + 0.005*"look"
# Topic: 187 Word: 0.435*"element" + 0.386*"route" + 0.028*"div" + 0.018*"inspect" + 0.018*"mat" + 0.005*"specific" + 0.004*"follow" + 0.004*"turbolink" + 0.003*"enemy" + 0.003*"different"
# Topic: 188 Word: 0.400*"authentication" + 0.105*"identity" + 0.095*"factory" + 0.094*"ad" + 0.081*"oauth" + 0.066*"basic" + 0.050*"authorization" + 0.021*"identityserver" + 0.019*"claim" + 0.012*"base"
# Topic: 189 Word: 0.199*"ssis" + 0.087*"endpoint" + 0.083*"credential" + 0.083*"upgrade" + 0.076*"dialogflow" + 0.060*"grpc" + 0.057*"electron" + 0.046*"iot" + 0.031*"slack" + 0.025*"packaging"
# Topic: 190 Word: 0.145*"car" + 0.119*"services_ssrs_ssr" + 0.036*"favicon" + 0.031*"virus" + 0.018*"sector" + 0.017*"botframework_bot" + 0.016*"damage" + 0.011*"referral" + 0.011*"appliance" + 0.010*"ota"
# Topic: 191 Word: 0.782*"powershell" + 0.091*"virtual" + 0.019*"var" + 0.006*"karate" + 0.005*"applicable" + 0.005*"sublime" + 0.005*"sorted" + 0.004*"genymotion" + 0.004*"flextable" + 0.004*"cmdlet"
# Topic: 192 Word: 0.179*"operate" + 0.168*"parent" + 0.139*"leaflet" + 0.137*"modal" + 0.078*"marker" + 0.041*"reactive_form" + 0.030*"replicate" + 0.024*"opening" + 0.021*"clicking" + 0.018*"fiddle"
# Topic: 193 Word: 0.560*"email" + 0.188*"address" + 0.036*"attachment" + 0.035*"confirm" + 0.017*"confirmation" + 0.014*"operating" + 0.008*"recipient" + 0.007*"reminder" + 0.006*"multiprocess" + 0.003*"simple"
# Topic: 194 Word: 0.257*"problem" + 0.244*"issue" + 0.118*"fix" + 0.085*"solve" + 0.034*"face" + 0.029*"repeat" + 0.029*"speech" + 0.024*"fine" + 0.021*"follow" + 0.017*"know"
# Topic: 195 Word: 0.385*"token" + 0.191*"retrieve" + 0.107*"valid" + 0.035*"recyclerview" + 0.024*"composite" + 0.023*"saving" + 0.015*"stretch" + 0.009*"gray" + 0.008*"sized" + 0.007*"able"
# Topic: 196 Word: 0.332*"display" + 0.139*"appear" + 0.099*"icon" + 0.088*"hide" + 0.038*"visible" + 0.035*"flatlist" + 0.027*"correctly" + 0.022*"disappear" + 0.014*"transparent" + 0.010*"flat"
# Topic: 197 Word: 0.185*"question" + 0.141*"solution" + 0.060*"similar" + 0.045*"ask" + 0.039*"answer" + 0.032*"know" + 0.028*"look" + 0.023*"problem" + 0.022*"possible" + 0.020*"suggest"
# Topic: 198 Word: 0.217*"probably" + 0.092*"sorry" + 0.049*"challenge" + 0.043*"daily" + 0.036*"groovy" + 0.036*"spock" + 0.025*"readline" + 0.023*"silly" + 0.020*"sapply" + 0.017*"glitch"
# Topic: 199 Word: 0.379*"hook" + 0.141*"effect" + 0.068*"term" + 0.062*"pre" + 0.059*"matlab" + 0.046*"lifecycle" + 0.042*"exchange" + 0.011*"andor" + 0.009*"rpc" + 0.009*"throttling"
# Topic: 200 Word: 0.517*"storage" + 0.303*"local" + 0.043*"blob" + 0.023*"ak" + 0.013*"quartz" + 0.008*"story" + 0.006*"wear" + 0.005*"iqueryable" + 0.003*"consumption" + 0.003*"precompile"
# Topic: 201 Word: 0.257*"parameter" + 0.253*"pass" + 0.165*"argument" + 0.086*"extract" + 0.066*"integer" + 0.031*"crawler" + 0.012*"subset" + 0.009*"explicit" + 0.008*"accept" + 0.006*"awk_se"
# Topic: 202 Word: 0.802*"swift" + 0.087*"vector" + 0.036*"ios" + 0.022*"combination" + 0.012*"apple_push_notification" + 0.007*"freeze" + 0.006*"safe" + 0.002*"uid" + 0.002*"traversal" + 0.001*"man"
# Topic: 203 Word: 0.282*"mvc" + 0.153*"asp" + 0.110*"oracle_plsql" + 0.088*"orm" + 0.036*"contenteditable" + 0.021*"consul" + 0.019*"artifactory" + 0.014*"npgsql" + 0.013*"resolver" + 0.012*"mediarecorder"
# Topic: 204 Word: 0.298*"merge" + 0.181*"push" + 0.121*"commit" + 0.099*"exit" + 0.059*"reload" + 0.031*"adword" + 0.020*"copying" + 0.019*"png" + 0.014*"seek" + 0.012*"mnist"
# Topic: 205 Word: 0.221*"debugging" + 0.087*"construct" + 0.061*"talend" + 0.057*"assert" + 0.045*"debugger" + 0.040*"substitution" + 0.038*"swipe" + 0.034*"hardcode" + 0.030*"pyodbc" + 0.028*"ugly"
# Topic: 206 Word: 0.393*"print" + 0.117*"printing" + 0.085*"pretty" + 0.047*"replication" + 0.041*"typeerror" + 0.029*"webassembly" + 0.028*"progress" + 0.023*"observe" + 0.023*"autolayout" + 0.022*"spyder"
# Topic: 207 Word: 0.462*"parse" + 0.154*"expression" + 0.102*"science" + 0.089*"common" + 0.039*"compression" + 0.015*"fold" + 0.014*"prefix" + 0.009*"arithmetic" + 0.007*"uitextfield" + 0.005*"delegation"
# Topic: 208 Word: 0.578*"variable" + 0.069*"level" + 0.065*"global" + 0.045*"regression" + 0.035*"declare" + 0.024*"assignment" + 0.016*"python" + 0.016*"inference" + 0.014*"linear_regression" + 0.014*"decode"
# Topic: 209 Word: 0.446*"manager" + 0.140*"relate" + 0.071*"restart" + 0.061*"related" + 0.036*"archive" + 0.025*"supply" + 0.014*"ngrok" + 0.009*"flavor" + 0.008*"reorder" + 0.008*"sortable"
# Topic: 210 Word: 0.159*"home" + 0.111*"parallel_processe" + 0.085*"parallel_processing" + 0.081*"macro" + 0.068*"away" + 0.039*"phrase" + 0.030*"efficiency" + 0.021*"near" + 0.017*"subtype" + 0.014*"algebra"
# Topic: 211 Word: 0.154*"regular" + 0.078*"ejs" + 0.049*"bulk" + 0.048*"summarize" + 0.040*"woocommerce_subscription" + 0.030*"xpage" + 0.029*"obfuscation" + 0.018*"plenty" + 0.017*"pagespeed_insight" + 0.015*"triple"
# Topic: 212 Word: 0.114*"hibernate" + 0.105*"pthread" + 0.085*"jdbc" + 0.070*"calculator" + 0.042*"richtextbox" + 0.032*"planning" + 0.028*"scala" + 0.025*"signin" + 0.023*"resultset" + 0.022*"encryption_ae"
# Topic: 213 Word: 0.340*"frontend" + 0.043*"conf" + 0.023*"tricky" + 0.021*"upstream" + 0.019*"uwsgi" + 0.018*"mitmproxy" + 0.016*"prerender" + 0.016*"prefetch" + 0.016*"dotnet_httpclient" + 0.014*"wallpaper"
# Topic: 214 Word: 0.224*"switch" + 0.181*"mode" + 0.103*"price" + 0.089*"localization" + 0.044*"kernel" + 0.029*"sprite" + 0.021*"fall" + 0.021*"max" + 0.020*"polyfill" + 0.019*"skill"
# Topic: 215 Word: 0.210*"analysis" + 0.192*"fabric" + 0.076*"accordion" + 0.063*"powerbi" + 0.037*"drawing" + 0.029*"sklearn" + 0.028*"actor" + 0.022*"char" + 0.021*"dlib" + 0.019*"executor"
# Topic: 216 Word: 0.300*"memory" + 0.235*"spark" + 0.112*"management" + 0.087*"job" + 0.073*"reactj" + 0.036*"warehouse" + 0.019*"usage" + 0.019*"alamofire" + 0.016*"enzyme" + 0.010*"allocate"
# Topic: 217 Word: 0.748*"event" + 0.042*"handler" + 0.032*"reverse" + 0.026*"raise" + 0.024*"concatenation" + 0.023*"stock" + 0.010*"tidyverse" + 0.005*"verbose" + 0.004*"eventemitter" + 0.004*"hadoop_hive_hiveql"
# Topic: 218 Word: 0.472*"script" + 0.199*"execute" + 0.073*"partition" + 0.026*"running" + 0.022*"overwrite" + 0.015*"follow" + 0.010*"fine" + 0.009*"velocity" + 0.005*"cgi" + 0.005*"mapreduce"
# Topic: 219 Word: 0.370*"filter" + 0.184*"apply" + 0.129*"highchart" + 0.111*"dataframe" + 0.068*"dialog" + 0.018*"frequency" + 0.015*"power" + 0.010*"coefficient" + 0.009*"circleci" + 0.009*"ngmodel"
# Topic: 220 Word: 0.328*"kotlin" + 0.154*"public" + 0.106*"pdf" + 0.103*"online" + 0.044*"void" + 0.043*"temp" + 0.018*"comparator" + 0.017*"buy" + 0.011*"flush" + 0.008*"lex"
# Topic: 221 Word: 0.335*"sequence" + 0.116*"pyqt" + 0.073*"exe" + 0.041*"diagram" + 0.036*"glob" + 0.034*"physical" + 0.032*"geocode" + 0.019*"bat" + 0.018*"oracledb" + 0.015*"quota"
# Topic: 222 Word: 0.345*"websocket" + 0.135*"live" + 0.133*"substre" + 0.047*"bracket" + 0.024*"netty" + 0.019*"localstorage" + 0.018*"notepad" + 0.015*"stringify" + 0.015*"admob_ad" + 0.012*"hard_code"
# Topic: 223 Word: 0.156*"auth" + 0.097*"concern" + 0.066*"oop_design_pattern" + 0.062*"deleting" + 0.046*"appointment" + 0.028*"marshalling" + 0.020*"tensorflow_estimator" + 0.017*"dreamweaver" + 0.016*"apis" + 0.014*"omniface"
# Topic: 224 Word: 0.238*"game" + 0.156*"player" + 0.131*"guess" + 0.108*"lose" + 0.057*"currency" + 0.023*"decrease" + 0.019*"constantly" + 0.014*"raster" + 0.010*"inefficient" + 0.010*"elevation"
# Topic: 225 Word: 0.561*"datum" + 0.158*"data" + 0.125*"structure" + 0.046*"frame" + 0.032*"transform" + 0.017*"flexbox" + 0.015*"panel" + 0.005*"divs" + 0.002*"base" + 0.002*"come"
# Topic: 226 Word: 0.414*"eloquent" + 0.152*"relationship" + 0.093*"closure" + 0.076*"openlayer" + 0.031*"trait" + 0.022*"shipping" + 0.020*"serial" + 0.020*"laravel" + 0.013*"family" + 0.008*"monthly"
# Topic: 227 Word: 0.250*"machine" + 0.242*"remote" + 0.213*"certificate" + 0.028*"dropzone" + 0.023*"ca" + 0.017*"trust" + 0.013*"pylint" + 0.011*"cert" + 0.007*"booking" + 0.006*"httpwebrequest"
# Topic: 228 Word: 0.127*"correlation" + 0.123*"sensor" + 0.096*"segment" + 0.089*"dump" + 0.062*"age" + 0.057*"slot" + 0.028*"incompatible" + 0.026*"uilabel" + 0.024*"smtp" + 0.014*"quarter"
# Topic: 229 Word: 0.346*"ionic" + 0.254*"load" + 0.171*"plugin" + 0.107*"audio" + 0.033*"loading" + 0.021*"exclude" + 0.005*"loaded" + 0.004*"intercept" + 0.003*"ontology" + 0.002*"lazy_loade"
# Topic: 230 Word: 0.211*"fetch" + 0.146*"selector" + 0.133*"aggregate" + 0.110*"unique" + 0.104*"total" + 0.033*"protect" + 0.030*"whitespace" + 0.025*"hierarchy" + 0.024*"echart" + 0.021*"thumbnail"
# Topic: 231 Word: 0.098*"converter" + 0.087*"period" + 0.067*"phpstorm" + 0.062*"destroy" + 0.041*"nlp" + 0.035*"rely" + 0.033*"protection" + 0.032*"guarantee" + 0.027*"isolate" + 0.025*"expansion"
# Topic: 232 Word: 0.848*"object" + 0.014*"destination" + 0.011*"interaction" + 0.007*"tibble" + 0.005*"dead" + 0.005*"timeline" + 0.004*"cp" + 0.004*"nonblocke" + 0.004*"different" + 0.004*"flux"
# Topic: 233 Word: 0.301*"mobile" + 0.139*"builder" + 0.131*"shiny" + 0.066*"metric" + 0.052*"drawable" + 0.041*"media_querie" + 0.034*"popover" + 0.025*"scheduling" + 0.009*"dedicated" + 0.008*"tabcontrol"
# Topic: 234 Word: 0.752*"unity" + 0.028*"postman" + 0.025*"carbon" + 0.014*"proptype" + 0.012*"teradata" + 0.009*"friendly" + 0.008*"deliver" + 0.008*"twist" + 0.008*"scrollable" + 0.008*"jmeter"
# Topic: 235 Word: 0.208*"carousel" + 0.058*"ngfor" + 0.047*"catalog" + 0.035*"explore" + 0.026*"unpack" + 0.021*"acquire" + 0.020*"stepper" + 0.020*"overview" + 0.017*"ii" + 0.017*"calayer"
# Topic: 236 Word: 0.297*"plot" + 0.208*"figure" + 0.118*"visualization" + 0.082*"produce" + 0.051*"ggplot" + 0.040*"gnuplot" + 0.031*"datetimepicker" + 0.012*"scatter" + 0.006*"different" + 0.006*"antd"
# Topic: 237 Word: 0.455*"embed" + 0.115*"picker" + 0.072*"mark" + 0.067*"jest" + 0.028*"wsdl" + 0.026*"uninstall" + 0.019*"minimize" + 0.017*"carthage" + 0.008*"codebase" + 0.008*"markup"
# Topic: 238 Word: 0.060*"think" + 0.053*"look" + 0.047*"know" + 0.046*"thing" + 0.046*"s" + 0.042*"bit" + 0.031*"problem" + 0.031*"sure" + 0.021*"maybe" + 0.018*"follow"
# Topic: 239 Word: 0.233*"count" + 0.219*"recursion" + 0.117*"aggregation" + 0.104*"volume" + 0.061*"pop" + 0.037*"normalization" + 0.022*"forever" + 0.011*"palindrome" + 0.011*"mime" + 0.009*"flicker"
# Topic: 240 Word: 0.563*"example" + 0.144*"com" + 0.071*"reflection" + 0.051*"installer" + 0.027*"piece" + 0.019*"propertie" + 0.016*"possible" + 0.012*"early" + 0.007*"simple" + 0.007*"board"
# Topic: 241 Word: 0.558*"window" + 0.133*"browser" + 0.069*"chrome" + 0.060*"scale" + 0.049*"resize" + 0.023*"eval" + 0.013*"popup" + 0.009*"shortcut" + 0.009*"pin" + 0.004*"fine"
# Topic: 242 Word: 0.343*"path" + 0.207*"download" + 0.143*"nuget" + 0.050*"addin" + 0.041*"enterprise" + 0.034*"mingw" + 0.033*"relative" + 0.015*"urllib" + 0.008*"escaping" + 0.007*"interpreter"
# Topic: 243 Word: 0.205*"architecture" + 0.177*"microservice" + 0.093*"clean" + 0.087*"distribute" + 0.078*"border" + 0.054*"cleaning" + 0.050*"dot" + 0.014*"scss" + 0.014*"pagespeed" + 0.014*"csproj"
# Topic: 244 Word: 0.728*"php" + 0.140*"bootstrap" + 0.095*"connection" + 0.005*"symfony_doctrine_orm" + 0.004*"cpanel" + 0.003*"establish" + 0.001*"buddypress" + 0.001*"chess" + 0.001*"pkcs" + 0.001*"simple"
# Topic: 245 Word: 0.420*"vision" + 0.055*"lazy_loading" + 0.052*"vagrant" + 0.048*"nestj" + 0.045*"collapse" + 0.042*"alter" + 0.037*"super" + 0.019*"convention" + 0.014*"tfrecord" + 0.013*"cypher"
# Topic: 246 Word: 0.649*"session" + 0.042*"coroutine" + 0.040*"spotify" + 0.038*"sentence" + 0.019*"annotate" + 0.009*"dirty" + 0.008*"val" + 0.007*"approximately" + 0.007*"implicit_conversion" + 0.006*"entropy"
# Topic: 247 Word: 0.593*"group" + 0.081*"serverless" + 0.044*"inner" + 0.036*"authorize" + 0.030*"dashboard" + 0.015*"outer" + 0.011*"grouping" + 0.010*"vote" + 0.009*"dojo" + 0.008*"candidate"
# Topic: 248 Word: 0.213*"camera" + 0.124*"twitter" + 0.117*"nosql" + 0.074*"placeholder" + 0.048*"devtool" + 0.041*"oledb" + 0.030*"inappbrowser" + 0.021*"pe" + 0.016*"redundant" + 0.014*"carrierwave"
# Topic: 249 Word: 0.756*"table" + 0.104*"insert" + 0.054*"mariadb" + 0.016*"liquibase" + 0.009*"multiple" + 0.005*"foreign_key" + 0.003*"ifstream" + 0.003*"different" + 0.002*"euclidean_distance" + 0.002*"look"
# Topic: 250 Word: 0.308*"panda" + 0.182*"indexing" + 0.151*"scrape" + 0.063*"ng" + 0.053*"override" + 0.049*"tfs" + 0.039*"article" + 0.024*"bean" + 0.010*"rxjs_observable" + 0.010*"homepage"
# Topic: 251 Word: 0.216*"deployment" + 0.124*"deploy" + 0.117*"release" + 0.115*"jar" + 0.109*"branch" + 0.048*"locally" + 0.041*"master" + 0.030*"conflict" + 0.022*"automate" + 0.019*"war"
# Topic: 252 Word: 0.683*"date" + 0.173*"difference" + 0.012*"iso" + 0.009*"breadcrumb" + 0.005*"powerbi_powerbi_desktop" + 0.004*"bottle" + 0.003*"unit_testing" + 0.003*"asyncsocket" + 0.003*"utc" + 0.003*"different"
# Topic: 253 Word: 0.261*"notification" + 0.181*"cast" + 0.112*"namespace" + 0.103*"push_notification" + 0.044*"concurrency" + 0.029*"communication" + 0.027*"hang" + 0.016*"casting" + 0.016*"demo" + 0.013*"happy"
# Topic: 254 Word: 0.206*"zip" + 0.144*"generator" + 0.127*"declaration" + 0.044*"unzip" + 0.023*"scaling" + 0.021*"memoization" + 0.020*"rascal" + 0.017*"technically" + 0.014*"urlfetch" + 0.010*"ellipse"
# Topic: 255 Word: 0.166*"classification" + 0.145*"machine_learne" + 0.143*"policy" + 0.080*"people" + 0.065*"person" + 0.061*"linker" + 0.056*"bucket" + 0.052*"razor_page" + 0.040*"subdomain" + 0.029*"perfect"
# Topic: 256 Word: 0.347*"boost" + 0.057*"plain" + 0.054*"outside" + 0.039*"autocomplete" + 0.038*"markdown" + 0.023*"clicked" + 0.022*"btw" + 0.018*"useless" + 0.018*"slideshow" + 0.018*"latex"
# Topic: 257 Word: 0.565*"post" + 0.122*"iteration" + 0.052*"creation" + 0.034*"admin" + 0.015*"slug" + 0.012*"receipt" + 0.012*"custom_taxonomy" + 0.012*"cgal" + 0.011*"url_rewriting" + 0.006*"bin"
# Topic: 258 Word: 0.335*"terminal" + 0.144*"inside" + 0.077*"navigate" + 0.046*"deep" + 0.043*"owner" + 0.034*"powerbi_powerbi_embedde" + 0.018*"difficulty" + 0.016*"redhat" + 0.013*"problematic" + 0.011*"mainactivity"
# Topic: 259 Word: 0.086*"versioning" + 0.084*"versione" + 0.063*"rancher" + 0.037*"wheel" + 0.033*"streamreader" + 0.020*"aapt" + 0.018*"investigation" + 0.016*"pandas" + 0.016*"drone" + 0.014*"titanium"
# Topic: 260 Word: 0.165*"cor" + 0.135*"enum" + 0.131*"pipe" + 0.114*"symbol" + 0.058*"region" + 0.045*"semantic" + 0.027*"origin" + 0.025*"persistence" + 0.022*"party" + 0.020*"locale"
# Topic: 261 Word: 0.382*"dart" + 0.277*"opencv" + 0.098*"detect" + 0.037*"circle" + 0.029*"crop" + 0.028*"scikit" + 0.015*"contour" + 0.012*"onedrive" + 0.012*"sublimetext" + 0.008*"template_argument_deduction"
# Topic: 262 Word: 0.190*"specify" + 0.147*"warning" + 0.120*"avoid" + 0.098*"ignore" + 0.068*"completely" + 0.053*"warn" + 0.035*"recommend" + 0.031*"explicitly" + 0.021*"pm" + 0.019*"callable"
# Topic: 263 Word: 0.547*"performance" + 0.051*"snippet" + 0.045*"slow" + 0.036*"fast" + 0.034*"efficient" + 0.028*"speed" + 0.024*"improve" + 0.022*"signalr" + 0.022*"measure" + 0.022*"scene"
# Topic: 264 Word: 0.322*"node" + 0.129*"kubernete" + 0.113*"encode" + 0.076*"encoding" + 0.063*"maker" + 0.055*"ubuntu" + 0.051*"letter" + 0.022*"pod" + 0.014*"linking" + 0.011*"spot"
# Topic: 265 Word: 0.500*"client" + 0.299*"folder" + 0.038*"locate" + 0.018*"intersection" + 0.006*"specific" + 0.006*"concrete" + 0.006*"different" + 0.005*"uploader" + 0.005*"fine" + 0.004*"multiple"
# Topic: 266 Word: 0.513*"statement" + 0.146*"runtime" + 0.071*"channel" + 0.038*"paste" + 0.036*"wrapper" + 0.032*"openssl" + 0.021*"orientation" + 0.018*"proceed" + 0.013*"activemq" + 0.007*"clarification"
# Topic: 267 Word: 0.158*"medium" + 0.112*"helper" + 0.092*"polymorphism" + 0.064*"wso" + 0.060*"deadlock" + 0.052*"polygon" + 0.031*"world" + 0.027*"recursively" + 0.027*"tostring" + 0.021*"webrtc"
# Topic: 268 Word: 0.305*"default" + 0.246*"copy" + 0.234*"constructor" + 0.018*"prototype" + 0.017*"instantiate" + 0.012*"forum" + 0.007*"fetching" + 0.007*"invite" + 0.005*"todo" + 0.004*"instead"
# Topic: 269 Word: 0.419*"http" + 0.218*"header" + 0.122*"detection" + 0.053*"protocol" + 0.039*"edge" + 0.033*"injection" + 0.009*"resharper" + 0.006*"csrf" + 0.004*"fusionchart" + 0.004*"orientdb"
# Topic: 270 Word: 0.587*"miss" + 0.031*"onload" + 0.028*"reactive" + 0.019*"cat" + 0.017*"docx" + 0.014*"ribbon" + 0.014*"imputation" + 0.011*"vsix" + 0.011*"subfolder" + 0.010*"ggplot_plotly_ggplotly"
# Topic: 271 Word: 0.369*"validation" + 0.221*"character" + 0.103*"box" + 0.066*"drop" + 0.053*"validate" + 0.036*"vectorization" + 0.024*"bigdata" + 0.022*"sale" + 0.013*"gzip" + 0.004*"sms"
# Topic: 272 Word: 0.263*"main" + 0.205*"activity" + 0.108*"fragment" + 0.102*"arraylist" + 0.055*"future" + 0.028*"recent" + 0.024*"bazel" + 0.018*"ts" + 0.015*"toggle" + 0.011*"indice"
# Topic: 273 Word: 0.491*"studio" + 0.477*"visual" + 0.008*"msbuild" + 0.007*"websphere" + 0.003*"plist" + 0.001*"exponential" + 0.001*"community" + 0.000*"cc" + 0.000*"accessory" + 0.000*"assemblyinfo"
# Topic: 274 Word: 0.747*"css" + 0.078*"position" + 0.072*"style" + 0.029*"height" + 0.013*"webpage" + 0.009*"drag" + 0.007*"vue" + 0.004*"whatsapp" + 0.004*"positioning" + 0.003*"shutdown"
# Topic: 275 Word: 0.519*"format" + 0.146*"space" + 0.053*"extra" + 0.038*"score" + 0.029*"unexpected" + 0.028*"cursor" + 0.018*"odd" + 0.013*"ex" + 0.009*"torch" + 0.008*"pdb"
# Topic: 276 Word: 0.497*"project" + 0.119*"setting" + 0.077*"setup" + 0.027*"redirection" + 0.025*"mask" + 0.018*"follow" + 0.018*"stripe_payment" + 0.014*"classic" + 0.010*"fine" + 0.010*"gradlew"
# Topic: 277 Word: 0.469*"pointer" + 0.149*"pull" + 0.070*"subscription" + 0.043*"bus" + 0.030*"passenger" + 0.019*"mobx" + 0.016*"smart_pointer" + 0.016*"smart" + 0.015*"motion" + 0.013*"transport"
# Topic: 278 Word: 0.712*"type" + 0.136*"generic" + 0.022*"associate" + 0.013*"terminate" + 0.009*"audit" + 0.007*"foo" + 0.005*"different" + 0.005*"erase" + 0.003*"preferably" + 0.003*"matcher"
# Topic: 279 Word: 0.583*"batch" + 0.082*"unit" + 0.040*"cpu" + 0.037*"employee" + 0.032*"primeface" + 0.025*"absolute" + 0.023*"inline" + 0.010*"pende" + 0.009*"aim" + 0.009*"getter"
# Topic: 280 Word: 0.620*"datatable" + 0.113*"ajax" + 0.042*"offset" + 0.019*"ram" + 0.016*"hierarchical" + 0.013*"solr" + 0.011*"arrange" + 0.011*"linkage" + 0.010*"organize" + 0.009*"postback"
# Topic: 281 Word: 0.401*"optimization" + 0.178*"constraint" + 0.100*"advanced" + 0.035*"serializer" + 0.032*"optimize" + 0.019*"vbscript" + 0.018*"solver" + 0.017*"repeater" + 0.016*"equality" + 0.016*"cardview"
# Topic: 282 Word: 0.450*"content" + 0.121*"length" + 0.047*"maximum" + 0.022*"identical" + 0.019*"privilege" + 0.018*"vary" + 0.018*"efficiently" + 0.016*"differ" + 0.015*"capacitor" + 0.012*"wizard"
# Topic: 283 Word: 0.850*"file" + 0.048*"directory" + 0.010*"filename" + 0.007*"multiple" + 0.006*"look" + 0.006*"follow" + 0.004*"different" + 0.003*"able" + 0.003*"specific" + 0.003*"know"
# Topic: 284 Word: 0.332*"automation" + 0.094*"active" + 0.079*"distance" + 0.072*"internet" + 0.062*"windows_subsystem_linux" + 0.060*"odbc" + 0.024*"finding" + 0.021*"anaconda" + 0.013*"gui" + 0.011*"opinion"
# Topic: 285 Word: 0.336*"split" + 0.238*"separate" + 0.049*"firestore" + 0.046*"divide" + 0.031*"vertical" + 0.030*"half" + 0.029*"horizontal" + 0.015*"multiple" + 0.015*"die" + 0.010*"discount"
# Topic: 286 Word: 0.551*"application" + 0.150*"console" + 0.067*"mapping" + 0.045*"external" + 0.023*"inject" + 0.017*"develop" + 0.015*"dependency_injection" + 0.012*"expose" + 0.008*"automapper" + 0.006*"fine"
# Topic: 287 Word: 0.155*"course" + 0.115*"free" + 0.081*"counter" + 0.073*"slice" + 0.068*"sense" + 0.043*"interested" + 0.036*"portion" + 0.027*"brand" + 0.023*"underlie" + 0.020*"potentially"
# Topic: 288 Word: 0.397*"resource" + 0.207*"manage" + 0.113*"ssm" + 0.068*"percentage" + 0.011*"testcontainer" + 0.009*"push_notification_apple_push" + 0.009*"hosting" + 0.007*"vnet" + 0.007*"owin" + 0.007*"distributed_computing_distribute"
# Topic: 289 Word: 0.103*"couchbase" + 0.100*"workaround" + 0.090*"simplify" + 0.066*"reproduce" + 0.050*"minimal" + 0.048*"multilingual" + 0.038*"mercurial" + 0.028*"googlet" + 0.027*"demonstrate" + 0.020*"cross_compile"
# Topic: 290 Word: 0.599*"database" + 0.177*"firebase" + 0.168*"realtime" + 0.029*"messaging" + 0.003*"psql" + 0.003*"mamp" + 0.001*"raycaste" + 0.001*"thunk" + 0.001*"resizable" + 0.001*"docusign"
# Topic: 291 Word: 0.397*"datepicker" + 0.116*"margin" + 0.042*"wise" + 0.035*"stat" + 0.023*"sdl" + 0.020*"temporal" + 0.015*"edittext" + 0.014*"multiplayer" + 0.013*"coin" + 0.013*"cleanup"
# Topic: 292 Word: 0.501*"array" + 0.324*"contain" + 0.033*"mining" + 0.011*"classloader" + 0.007*"look" + 0.005*"specific" + 0.005*"multiple" + 0.003*"datalist" + 0.003*"follow" + 0.003*"correlate"
# Topic: 293 Word: 0.475*"action" + 0.105*"area" + 0.045*"prism" + 0.040*"youtube" + 0.032*"zoom" + 0.032*"reply" + 0.028*"iframe" + 0.023*"rating" + 0.012*"updating" + 0.009*"ws"
# Topic: 294 Word: 0.371*"extension" + 0.141*"arm" + 0.139*"curl" + 0.088*"drive" + 0.061*"hard" + 0.047*"extraction" + 0.017*"httpresponse" + 0.007*"shorten" + 0.004*"opencart" + 0.004*"landing"
# Topic: 295 Word: 0.576*"number" + 0.106*"random" + 0.048*"increase" + 0.028*"determine" + 0.025*"digit" + 0.020*"increment" + 0.014*"dask_dask_distribute" + 0.013*"observation" + 0.011*"rspec" + 0.010*"newline"
# Topic: 296 Word: 0.187*"protractor" + 0.173*"cakephp" + 0.119*"dynamodb" + 0.090*"iis" + 0.075*"failure" + 0.047*"doctrine" + 0.040*"crystal_report" + 0.021*"allure" + 0.014*"pageobject" + 0.012*"entrie"
# Topic: 297 Word: 0.240*"sample" + 0.072*"rate" + 0.063*"depth" + 0.058*"overlap" + 0.046*"spreadsheet" + 0.045*"variant" + 0.042*"visit" + 0.038*"dbcontext" + 0.029*"retrofit" + 0.026*"compatible"
# Topic: 298 Word: 0.446*"cookie" + 0.100*"login" + 0.078*"successful" + 0.059*"rest_assure" + 0.032*"remember" + 0.027*"subsequent" + 0.021*"logout" + 0.018*"captcha" + 0.017*"paypal" + 0.014*"refactoring"
# Topic: 299 Word: 0.887*"azure" + 0.056*"devop" + 0.008*"eventhub" + 0.008*"backup" + 0.007*"keyvault" + 0.003*"portal" + 0.003*"principal" + 0.002*"vst" + 0.002*"rust_lifetime" + 0.001*"servicebus_topic"

# %%
lda_model.save(datapath(base_model_lda + "model_semi_final"))

# %%
def get_text_bow(text):
    text = preprocess(text)
    text = make_trigrams([text])[0]
    text = lemmatization([text])[0]
    bow_vector = dictionary.doc2bow(text)
    return bow_vector

def test_texts(text1, text2):
    bow1 = get_text_bow(text1)
    bow2 = get_text_bow(text2)
    for index, score in sorted(lda_model[bow1], key=lambda tup: -1*tup[1]):
        print(f"index: {index}, score {score}")
        #print("Score: {}\t Topic: {}".format(score, lda_model.print_topic(index, 5)))
    print("_________________________________________")
    for index, score in sorted(lda_model[bow2], key=lambda tup: -1*tup[1]):
        print(f"index: {index}, score {score}")

# %%
data = pd.read_csv(base_dataset + 'large_data.csv')
data = data.head(DOC_COUNT)

# %%
row_n = 12
test_texts(data.loc[row_n, 'post_title'], data.loc[row_n, 'post_body'])
text1 = """VBA importing udf module from Add In to Workbook"""
text2 = """(TypeError: Cannot set property 'next' of null) When trying to make a linkedlist?"""
#test_texts(text1, text2)
print("______________________________")
print(data.loc[row_n, 'post_title'])
print("______________________________")
print(data.loc[row_n, 'post_body'])
# Out:
# index: 208, score 0.3270482122898102
# index: 171, score 0.27251410484313965
# index: 297, score 0.2024327516555786
# _________________________________________
# index: 171, score 0.48688679933547974
# index: 154, score 0.07441804558038712
# index: 204, score 0.07163151353597641
# index: 149, score 0.07157592475414276
# index: 91, score 0.039860039949417114
# index: 240, score 0.03905803710222244
# index: 41, score 0.03845934197306633
# index: 73, score 0.036128051578998566
# index: 136, score 0.03595936670899391
# index: 98, score 0.035835426300764084
# index: 250, score 0.03577928990125656
# ______________________________
# Overlap multiple images at some pixel level using Imagemagick
# ______________________________
# <p>For example, I have 4 images with a size of <strong>1000x800</strong>. I want to merge all these images into one image. I know there is a command of </p>
#
# <pre><code>convert +append image[1-4].jpg output.jpg
# </code></pre>
#
# <p>But I want to merge the second image into the first image by <strong>overlapping</strong> 250 pixels. </p>
#
# <p>i.e., In my final image, image1 has 750 pixels as well as image2 &amp; 3 and the last image has 1000 pixels. </p>
#
# <p>By using above <em>convert</em> command, we will get an image size of <strong>4000x800</strong>, but here I want it to be ((750*3)+1000*1)x800. i.e., <strong>3250x800</strong>.</p>
#
# <p>Also, how can I do this by appending vertically?</p>

# %%
def jensen_shannon_v(p, q):
    p = p[None,:].T
    q = q[None,:].T
    m = 0.5*(p + q)
    return np.sqrt(0.5*(entropy(p,m) + entropy(q,m)))

def title_body_sim(text1, text2, n_topics):
    bow1 = get_text_bow(text1)
    bow2 = get_text_bow(text2)
    p = np.zeros(n_topics)
    q = np.zeros(n_topics)
    for index, score in sorted(lda_model[bow1], key=lambda tup: -1*tup[1]):
        p[index] = score
    for index, score in sorted(lda_model[bow2], key=lambda tup: -1*tup[1]):
        q[index] = score
    return jensen_shannon_v(p, q)

# %%
title_body_sim(data.loc[row_n, 'post_title'], data.loc[row_n, 'post_body'], lda_model.num_topics)
#title_body_sim(text1, text2, lda_model.num_topics)
# Out:
# array([0.64129337])
